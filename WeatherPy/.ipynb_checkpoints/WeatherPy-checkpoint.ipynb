# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "document/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "https://api.openweathermap.org/data/2.5/weather?q=" + city + "&appid=" + weather_api_key
test_response = requests.get(url)
#print(test_response, url)

i = 1
city_holder = []
set_count = 1

for city in cities:
    try:
        if i == 50:
            set_count = set_count + 1
            i = 0
        print("Processing Record " + str(i) + " of Set " + str(set_count) + " | " + (city))
        url = "https://api.openweathermap.org/data/2.5/weather?q=" + city + "&appid=" + weather_api_key
        i= i + 1
    
    
        weather_response = requests.get(url)
        test_response = weather_response.json()

        #print(url)

        cloud = test_response["clouds"]["all"]
        country = test_response["sys"]["country"]
        date = test_response["dt"]
        humidity = test_response["main"]["humidity"]
        lat = test_response["coord"]["lat"]
        lng = test_response["coord"]["lon"]
        Max_temp = test_response["main"]["temp_max"]
        Wind_speed = test_response["wind"]["speed"]

        city_holder.append({"City" : city, "Cloudiness" : cloud, "Country": country, 
                            "Date" : date, "Humidity" : humidity, "Lat" : lat, "Lng" : lng, 
                            "Max Temp" : Max_temp, "Wind Speed" : Wind_speed})
        city_holder
    except: 
        print(city + "not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1| port blair
# Processing Record 2 of Set 1| ushuaia
# Processing Record 3 of Set 1| vaini
# Processing Record 4 of Set 1| portland
# Processing Record 5 of Set 1| xinxiang
# Processing Record 6 of Set 1| pangnirtung
# Processing Record 7 of Set 1| novyy urengoy
# Processing Record 8 of Set 1| rayevskiy
# Processing Record 9 of Set 1| mar del plata
# Processing Record 10 of Set 1| suzu
# suzunot found. Skipping...
# Processing Record 11 of Set 1| cazaje
# cazajenot found. Skipping...
# Processing Record 12 of Set 1| hasaki
# Processing Record 13 of Set 1| tautira
# Processing Record 14 of Set 1| te anau
# Processing Record 15 of Set 1| banepa
# Processing Record 16 of Set 1| hithadhoo
# Processing Record 17 of Set 1| kawalu
# Processing Record 18 of Set 1| faya
# Processing Record 19 of Set 1| new norfolk
# Processing Record 20 of Set 1| kananga
# Processing Record 21 of Set 1| albany
# Processing Record 22 of Set 1| rikitea
# Processing Record 23 of Set 1| hobart
# Processing Record 24 of Set 1| cape town
# Processing Record 25 of Set 1| bakel
# Processing Record 26 of Set 1| bay roberts
# Processing Record 27 of Set 1| bonthe
# Processing Record 28 of Set 1| butaritari
# Processing Record 29 of Set 1| yellowknife
# Processing Record 30 of Set 1| sturgeon falls
# Processing Record 31 of Set 1| lagoa
# Processing Record 32 of Set 1| bluff
# Processing Record 33 of Set 1| punta arenas
# Processing Record 34 of Set 1| amderma
# amdermanot found. Skipping...
# Processing Record 35 of Set 1| castro
# Processing Record 36 of Set 1| yusva
# yusvanot found. Skipping...
# Processing Record 37 of Set 1| kapaa
# Processing Record 38 of Set 1| souillac
# Processing Record 39 of Set 1| torbay
# Processing Record 40 of Set 1| dongsheng
# Processing Record 41 of Set 1| jamestown
# Processing Record 42 of Set 1| new port richey
# Processing Record 43 of Set 1| buraydah
# Processing Record 44 of Set 1| kahului
# Processing Record 45 of Set 1| evensk
# Processing Record 46 of Set 1| ormara
# Processing Record 47 of Set 1| krasnoselkup
# Processing Record 48 of Set 1| banda aceh
# Processing Record 49 of Set 1| shingu
# Processing Record 0 of Set 2| richards bay
# Processing Record 1 of Set 2| fortuna
# Processing Record 2 of Set 2| barrow
# Processing Record 3 of Set 2| porosozero
# Processing Record 4 of Set 2| bethel
# Processing Record 5 of Set 2| olafsvik
# Processing Record 6 of Set 2| pangody
# Processing Record 7 of Set 2| isla mujeres
# Processing Record 8 of Set 2| iqaluit
# Processing Record 9 of Set 2| chuy
# Processing Record 10 of Set 2| sao joao da barra
# Processing Record 11 of Set 2| hovd
# Processing Record 12 of Set 2| ribeira grande
# Processing Record 13 of Set 2| illoqqortoormiut
# illoqqortoormiutnot found. Skipping...
# Processing Record 14 of Set 2| taolanaro
# taolanaronot found. Skipping...
# Processing Record 15 of Set 2| wajima
# Processing Record 16 of Set 2| cabra
# Processing Record 17 of Set 2| clyde river
# Processing Record 18 of Set 2| east london
# Processing Record 19 of Set 2| kruisfontein
# Processing Record 20 of Set 2| clearlake
# Processing Record 21 of Set 2| mount isa
# Processing Record 22 of Set 2| ancud
# Processing Record 23 of Set 2| qaanaaq
# Processing Record 24 of Set 2| nuuk
# Processing Record 25 of Set 2| honningsvag
# Processing Record 26 of Set 2| padmanabhapuram
# Processing Record 27 of Set 2| mantua
# Processing Record 28 of Set 2| faanui
# Processing Record 29 of Set 2| namibe
# Processing Record 30 of Set 2| ternate
# Processing Record 31 of Set 2| port alfred
# Processing Record 32 of Set 2| buala
# Processing Record 33 of Set 2| zhangye
# Processing Record 34 of Set 2| kilindoni
# Processing Record 35 of Set 2| okhotsk
# Processing Record 36 of Set 2| baruun-urt
# Processing Record 37 of Set 2| hermanus
# Processing Record 38 of Set 2| bredasdorp
# Processing Record 39 of Set 2| carutapera
# Processing Record 40 of Set 2| narsaq
# Processing Record 41 of Set 2| nizhniy odes
# Processing Record 42 of Set 2| tura
# Processing Record 43 of Set 2| hobyo
# Processing Record 44 of Set 2| tsihombe
# tsihombenot found. Skipping...
# Processing Record 45 of Set 2| sinop
# Processing Record 46 of Set 2| camacha
# Processing Record 47 of Set 2| farmington
# Processing Record 48 of Set 2| ostersund
# Processing Record 49 of Set 2| bhola
# Processing Record 0 of Set 3| champerico
# Processing Record 1 of Set 3| zhanaozen
# Processing Record 2 of Set 3| airai
# Processing Record 3 of Set 3| port elizabeth
# Processing Record 4 of Set 3| sioux lookout
# Processing Record 5 of Set 3| tuktoyaktuk
# Processing Record 6 of Set 3| aykhal
# Processing Record 7 of Set 3| atuona
# Processing Record 8 of Set 3| saint-philippe
# Processing Record 9 of Set 3| cukai
# Processing Record 10 of Set 3| kholtoson
# Processing Record 11 of Set 3| port hedland
# Processing Record 12 of Set 3| basco
# Processing Record 13 of Set 3| mataura
# Processing Record 14 of Set 3| vila velha
# Processing Record 15 of Set 3| urdzhar
# urdzharnot found. Skipping...
# Processing Record 16 of Set 3| tuatapere
# Processing Record 17 of Set 3| college
# Processing Record 18 of Set 3| liminangcong
# liminangcongnot found. Skipping...
# Processing Record 19 of Set 3| yirol
# yirolnot found. Skipping...
# Processing Record 20 of Set 3| vohibinany
# Processing Record 21 of Set 3| mount gambier
# Processing Record 22 of Set 3| ferrol
# Processing Record 23 of Set 3| cleveland
# Processing Record 24 of Set 3| vardo
# Processing Record 25 of Set 3| weligama
# Processing Record 26 of Set 3| busselton
# Processing Record 27 of Set 3| pevek
# Processing Record 28 of Set 3| buqayq
# buqayqnot found. Skipping...
# Processing Record 29 of Set 3| tokur
# Processing Record 30 of Set 3| muros
# Processing Record 31 of Set 3| wenling
# Processing Record 32 of Set 3| derzhavinsk
# Processing Record 33 of Set 3| lenger
# Processing Record 34 of Set 3| longyearbyen
# Processing Record 35 of Set 3| chokurdakh
# Processing Record 36 of Set 3| madang
# Processing Record 37 of Set 3| kavieng
# Processing Record 38 of Set 3| sept-iles
# Processing Record 39 of Set 3| grand gaube
# Processing Record 40 of Set 3| chernyshevskiy
# Processing Record 41 of Set 3| choya
# Processing Record 42 of Set 3| abu dhabi
# Processing Record 43 of Set 3| valence
# Processing Record 44 of Set 3| buctzotz
# Processing Record 45 of Set 3| yerofey pavlovich
# Processing Record 46 of Set 3| norman wells
# Processing Record 47 of Set 3| arraial do cabo
# Processing Record 48 of Set 3| bail hongal
# Processing Record 49 of Set 3| huarmey
# Processing Record 0 of Set 4| nemuro
# Processing Record 1 of Set 4| puerto ayora
# Processing Record 2 of Set 4| shache
# Processing Record 3 of Set 4| carnarvon
# Processing Record 4 of Set 4| dikson
# Processing Record 5 of Set 4| vestmannaeyjar
# Processing Record 6 of Set 4| avarua
# Processing Record 7 of Set 4| vaitupu
# vaitupunot found. Skipping...
# Processing Record 8 of Set 4| korla
# Processing Record 9 of Set 4| toyooka
# Processing Record 10 of Set 4| cabo san lucas
# Processing Record 11 of Set 4| srednekolymsk
# Processing Record 12 of Set 4| quatre cocos
# Processing Record 13 of Set 4| tokmak
# Processing Record 14 of Set 4| cozumel
# Processing Record 15 of Set 4| mocuba
# Processing Record 16 of Set 4| isangel
# Processing Record 17 of Set 4| shetpe
# Processing Record 18 of Set 4| esperance
# Processing Record 19 of Set 4| neder vindinge
# Processing Record 20 of Set 4| sao filipe
# Processing Record 21 of Set 4| konstantinovka
# Processing Record 22 of Set 4| prainha
# Processing Record 23 of Set 4| porto novo
# Processing Record 24 of Set 4| mys shmidta
# mys shmidtanot found. Skipping...
# Processing Record 25 of Set 4| severo-kurilsk
# Processing Record 26 of Set 4| bolobo
# Processing Record 27 of Set 4| gazli
# Processing Record 28 of Set 4| yeletskiy
# yeletskiynot found. Skipping...
# Processing Record 29 of Set 4| rio gallegos
# Processing Record 30 of Set 4| ambon
# Processing Record 31 of Set 4| zhezkazgan
# Processing Record 32 of Set 4| barentsburg
# barentsburgnot found. Skipping...
# Processing Record 33 of Set 4| alofi
# Processing Record 34 of Set 4| sevsk
# Processing Record 35 of Set 4| chabahar
# Processing Record 36 of Set 4| tecpan
# Processing Record 37 of Set 4| nelson bay
# Processing Record 38 of Set 4| ugoofaaru
# Processing Record 39 of Set 4| lamu
# Processing Record 40 of Set 4| geraldton
# Processing Record 41 of Set 4| lolua
# loluanot found. Skipping...
# Processing Record 42 of Set 4| ituporanga
# Processing Record 43 of Set 4| tasiilaq
# Processing Record 44 of Set 4| carlsbad
# Processing Record 45 of Set 4| husavik
# Processing Record 46 of Set 4| leningradskiy
# Processing Record 47 of Set 4| hongjiang
# Processing Record 48 of Set 4| guhagar
# Processing Record 49 of Set 4| vostok
# Processing Record 0 of Set 5| palasa
# Processing Record 1 of Set 5| lebu
# Processing Record 2 of Set 5| ponta delgada
# Processing Record 3 of Set 5| batemans bay
# Processing Record 4 of Set 5| sainte-marie
# Processing Record 5 of Set 5| kaitangata
# Processing Record 6 of Set 5| lakselv
# Processing Record 7 of Set 5| qalyub
# Processing Record 8 of Set 5| ayr
# Processing Record 9 of Set 5| salalah
# Processing Record 10 of Set 5| nikolskoye
# Processing Record 11 of Set 5| takoradi
# Processing Record 12 of Set 5| osypenko
# Processing Record 13 of Set 5| san cristobal
# Processing Record 14 of Set 5| dong hoi
# Processing Record 15 of Set 5| lavrentiya
# Processing Record 16 of Set 5| maniitsoq
# Processing Record 17 of Set 5| tiksi
# Processing Record 18 of Set 5| jeremie
# Processing Record 19 of Set 5| cherskiy
# Processing Record 20 of Set 5| monrovia
# Processing Record 21 of Set 5| shirokiy
# Processing Record 22 of Set 5| thompson
# Processing Record 23 of Set 5| hongan
# hongannot found. Skipping...
# Processing Record 24 of Set 5| mahebourg
# Processing Record 25 of Set 5| jalu
# Processing Record 26 of Set 5| zhaoyuan
# Processing Record 27 of Set 5| saskylakh
# Processing Record 28 of Set 5| labuan
# Processing Record 29 of Set 5| palana
# Processing Record 30 of Set 5| flinders
# Processing Record 31 of Set 5| tarko-sale
# Processing Record 32 of Set 5| aklavik
# Processing Record 33 of Set 5| belushya guba
# belushya gubanot found. Skipping...
# Processing Record 34 of Set 5| rawatsar
# Processing Record 35 of Set 5| petropavlovsk-kamchatskiy
# Processing Record 36 of Set 5| quchan
# Processing Record 37 of Set 5| otatitlan
# Processing Record 38 of Set 5| poum
# Processing Record 39 of Set 5| upernavik
# Processing Record 40 of Set 5| eureka
# Processing Record 41 of Set 5| vila franca do campo
# Processing Record 42 of Set 5| dwarka
# Processing Record 43 of Set 5| ivanteyevka
# Processing Record 44 of Set 5| caucaia
# Processing Record 45 of Set 5| antofagasta
# Processing Record 46 of Set 5| safaga
# Processing Record 47 of Set 5| roma
# Processing Record 48 of Set 5| pacific grove
# Processing Record 49 of Set 5| kamenka
# Processing Record 0 of Set 6| valley
# Processing Record 1 of Set 6| zdvinsk
# Processing Record 2 of Set 6| risaralda
# Processing Record 3 of Set 6| bilibino
# Processing Record 4 of Set 6| eskasem
# eskasemnot found. Skipping...
# Processing Record 5 of Set 6| adrar
# Processing Record 6 of Set 6| san felipe
# Processing Record 7 of Set 6| zhuanghe
# Processing Record 8 of Set 6| xining
# Processing Record 9 of Set 6| bubaque
# Processing Record 10 of Set 6| asyut
# Processing Record 11 of Set 6| obluche
# obluchenot found. Skipping...
# Processing Record 12 of Set 6| arlit
# Processing Record 13 of Set 6| henties bay
# Processing Record 14 of Set 6| umzimvubu
# umzimvubunot found. Skipping...
# Processing Record 15 of Set 6| fort saint john
# fort saint johnnot found. Skipping...
# Processing Record 16 of Set 6| doctor pedro p. pena
# doctor pedro p. penanot found. Skipping...
# Processing Record 17 of Set 6| tignere
# Processing Record 18 of Set 6| canmore
# Processing Record 19 of Set 6| kloulklubed
# Processing Record 20 of Set 6| hamilton
# Processing Record 21 of Set 6| auki
# Processing Record 22 of Set 6| broome
# Processing Record 23 of Set 6| beringovskiy
# Processing Record 24 of Set 6| zhanakorgan
# Processing Record 25 of Set 6| lianzhou
# Processing Record 26 of Set 6| praia da vitoria
# Processing Record 27 of Set 6| georgetown
# Processing Record 28 of Set 6| melfi
# Processing Record 29 of Set 6| hihifo
# hihifonot found. Skipping...
# Processing Record 30 of Set 6| palabuhanratu
# palabuhanratunot found. Skipping...
# Processing Record 31 of Set 6| ketchikan
# Processing Record 32 of Set 6| victoria
# Processing Record 33 of Set 6| robertsport
# Processing Record 34 of Set 6| vanimo
# Processing Record 35 of Set 6| grand baie
# Processing Record 36 of Set 6| omboue
# Processing Record 37 of Set 6| manicore
# Processing Record 38 of Set 6| santa cruz do sul
# Processing Record 39 of Set 6| smithers
# Processing Record 40 of Set 6| kurilsk
# Processing Record 41 of Set 6| bac lieu
# Processing Record 42 of Set 6| joshimath
# Processing Record 43 of Set 6| taoudenni
# Processing Record 44 of Set 6| wallenhorst
# Processing Record 45 of Set 6| sataua
# satauanot found. Skipping...
# Processing Record 46 of Set 6| poitiers
# Processing Record 47 of Set 6| sant julia de loria
# Processing Record 48 of Set 6| los llanos de aridane
# Processing Record 49 of Set 6| attawapiskat
# attawapiskatnot found. Skipping...
# Processing Record 0 of Set 7| ponta do sol
# Processing Record 1 of Set 7| kokopo
# Processing Record 2 of Set 7| fetesti
# Processing Record 3 of Set 7| hearst
# Processing Record 4 of Set 7| marsh harbour
# Processing Record 5 of Set 7| guerrero negro
# Processing Record 6 of Set 7| tshikapa
# Processing Record 7 of Set 7| middle island
# Processing Record 8 of Set 7| nanortalik
# Processing Record 9 of Set 7| jablah
# Processing Record 10 of Set 7| aporawan
# aporawannot found. Skipping...
# Processing Record 11 of Set 7| ozernovskiy
# Processing Record 12 of Set 7| solnechnyy
# Processing Record 13 of Set 7| puerto baquerizo moreno
# Processing Record 14 of Set 7| bogatynia
# Processing Record 15 of Set 7| hilo
# Processing Record 16 of Set 7| katangli
# Processing Record 17 of Set 7| san rafael del sur
# Processing Record 18 of Set 7| great yarmouth
# Processing Record 19 of Set 7| torrington
# Processing Record 20 of Set 7| ambilobe
# Processing Record 21 of Set 7| banjar
# Processing Record 22 of Set 7| siva
# Processing Record 23 of Set 7| tambun
# Processing Record 24 of Set 7| dustlik
# Processing Record 25 of Set 7| falmouth
# Processing Record 26 of Set 7| kailua
# Processing Record 27 of Set 7| shitanjing
# Processing Record 28 of Set 7| louisbourg
# louisbourgnot found. Skipping...
# Processing Record 29 of Set 7| bathsheba
# Processing Record 30 of Set 7| tabou
# Processing Record 31 of Set 7| dunedin
# Processing Record 32 of Set 7| newport
# Processing Record 33 of Set 7| wilmington
# Processing Record 34 of Set 7| sinnamary
# Processing Record 35 of Set 7| kikwit
# Processing Record 36 of Set 7| mathathane
# Processing Record 37 of Set 7| middletown
# Processing Record 38 of Set 7| necochea
# Processing Record 39 of Set 7| provideniya
# Processing Record 40 of Set 7| kawana waters
# kawana watersnot found. Skipping...
# Processing Record 41 of Set 7| hervey bay
# Processing Record 42 of Set 7| khandyga
# Processing Record 43 of Set 7| bombay
# Processing Record 44 of Set 7| langfang
# Processing Record 45 of Set 7| fallon
# Processing Record 46 of Set 7| palmas
# Processing Record 47 of Set 7| rio grande
# Processing Record 48 of Set 7| si sa ket
# Processing Record 49 of Set 7| acajutla
# Processing Record 0 of Set 8| vao
# Processing Record 1 of Set 8| yerbogachen
# Processing Record 2 of Set 8| maneadero
# Processing Record 3 of Set 8| sri aman
# Processing Record 4 of Set 8| swift current
# Processing Record 5 of Set 8| mullaitivu
# mullaitivunot found. Skipping...
# Processing Record 6 of Set 8| klyuchi
# Processing Record 7 of Set 8| andapa
# Processing Record 8 of Set 8| santa isabel
# Processing Record 9 of Set 8| naze
# Processing Record 10 of Set 8| nishihara
# Processing Record 11 of Set 8| saint-augustin
# Processing Record 12 of Set 8| mayo
# Processing Record 13 of Set 8| makakilo city
# Processing Record 14 of Set 8| kodiak
# Processing Record 15 of Set 8| urucara
# Processing Record 16 of Set 8| mayna
# Processing Record 17 of Set 8| camapua
# Processing Record 18 of Set 8| khatanga
# Processing Record 19 of Set 8| maneromango
# Processing Record 20 of Set 8| sahrak
# sahraknot found. Skipping...
# Processing Record 21 of Set 8| itarema
# Processing Record 22 of Set 8| le port
# Processing Record 23 of Set 8| krasnyy chikoy
# Processing Record 24 of Set 8| semnan
# Processing Record 25 of Set 8| beroroha
# Processing Record 26 of Set 8| lata
# Processing Record 27 of Set 8| lompoc
# Processing Record 28 of Set 8| camocim
# Processing Record 29 of Set 8| saleaula
# saleaulanot found. Skipping...
# Processing Record 30 of Set 8| acari
# Processing Record 31 of Set 8| bengkulu
# Processing Record 32 of Set 8| yulara
# Processing Record 33 of Set 8| ostrovnoy
# Processing Record 34 of Set 8| sorland
# Processing Record 35 of Set 8| sambava
# Processing Record 36 of Set 8| port macquarie
# Processing Record 37 of Set 8| panzhihua
# Processing Record 38 of Set 8| abu samrah
# Processing Record 39 of Set 8| morden
# Processing Record 40 of Set 8| emba
# Processing Record 41 of Set 8| tubuala
# Processing Record 42 of Set 8| karratha
# Processing Record 43 of Set 8| barbastro
# Processing Record 44 of Set 8| udachnyy
# Processing Record 45 of Set 8| alyangula
# Processing Record 46 of Set 8| port lincoln
# Processing Record 47 of Set 8| marshall
# Processing Record 48 of Set 8| bondoukou
# Processing Record 49 of Set 8| cracow
# Processing Record 0 of Set 9| esmeralda
# Processing Record 1 of Set 9| cortez
# Processing Record 2 of Set 9| samusu
# samusunot found. Skipping...
# Processing Record 3 of Set 9| inderborskiy
# inderborskiynot found. Skipping...
# Processing Record 4 of Set 9| lasa
# Processing Record 5 of Set 9| avera
# Processing Record 6 of Set 9| saldanha
# Processing Record 7 of Set 9| tromso
# Processing Record 8 of Set 9| omsukchan
# Processing Record 9 of Set 9| forestville
# Processing Record 10 of Set 9| bedele
# Processing Record 11 of Set 9| kiama
# Processing Record 12 of Set 9| savannah bight
# Processing Record 13 of Set 9| kavaratti
# Processing Record 14 of Set 9| haines junction
# Processing Record 15 of Set 9| canaries
# Processing Record 16 of Set 9| gazalkent
# Processing Record 17 of Set 9| ixtapa
# Processing Record 18 of Set 9| sembe
# Processing Record 19 of Set 9| coro
# Processing Record 20 of Set 9| kirillov
# Processing Record 21 of Set 9| valparai
# Processing Record 22 of Set 9| sur
# Processing Record 23 of Set 9| karaton
# Processing Record 24 of Set 9| presidente franco
# Processing Record 25 of Set 9| ilulissat
# Processing Record 26 of Set 9| mosalsk
# Processing Record 27 of Set 9| businga
# Processing Record 28 of Set 9| ransang
# Processing Record 29 of Set 9| gogrial
# Processing Record 30 of Set 9| okakarara
# Processing Record 31 of Set 9| diamantino
# Processing Record 32 of Set 9| tejupilco
# tejupilconot found. Skipping...
# Processing Record 33 of Set 9| nome
# Processing Record 34 of Set 9| funtua
# Processing Record 35 of Set 9| borba
# Processing Record 36 of Set 9| juneau
# Processing Record 37 of Set 9| muroto
# Processing Record 38 of Set 9| malwan
# malwannot found. Skipping...
# Processing Record 39 of Set 9| praia
# Processing Record 40 of Set 9| sovetskiy
# Processing Record 41 of Set 9| dzhusaly
# dzhusalynot found. Skipping...
# Processing Record 42 of Set 9| karaul
# karaulnot found. Skipping...
# Processing Record 43 of Set 9| witrivier
# witriviernot found. Skipping...
# Processing Record 44 of Set 9| garissa
# Processing Record 45 of Set 9| luderitz
# Processing Record 46 of Set 9| chagda
# chagdanot found. Skipping...
# Processing Record 47 of Set 9| samarai
# Processing Record 48 of Set 9| saint-joseph
# Processing Record 49 of Set 9| vernon
# Processing Record 0 of Set 10| jiaojiang
# Processing Record 1 of Set 10| temaraia
# temaraianot found. Skipping...
# Processing Record 2 of Set 10| coquimbo
# Processing Record 3 of Set 10| ewa beach
# Processing Record 4 of Set 10| bellingham
# Processing Record 5 of Set 10| ahipara
# Processing Record 6 of Set 10| la ronge
# Processing Record 7 of Set 10| katra
# Processing Record 8 of Set 10| deputatskiy
# Processing Record 9 of Set 10| mount pleasant
# Processing Record 10 of Set 10| mentok
# mentoknot found. Skipping...
# Processing Record 11 of Set 10| moroni
# Processing Record 12 of Set 10| fauske
# Processing Record 13 of Set 10| kendari
# Processing Record 14 of Set 10| codajas
# Processing Record 15 of Set 10| gerash
# Processing Record 16 of Set 10| bastia
# Processing Record 17 of Set 10| nantucket
# Processing Record 18 of Set 10| atar
# Processing Record 19 of Set 10| nacala
# Processing Record 20 of Set 10| sitka
# Processing Record 21 of Set 10| atambua
# Processing Record 22 of Set 10| brownsville
# Processing Record 23 of Set 10| tapaua
# tapauanot found. Skipping...
# Processing Record 24 of Set 10| genhe
# Processing Record 25 of Set 10| rocha
# Processing Record 26 of Set 10| bambous virieux
# Processing Record 27 of Set 10| dondo
# Processing Record 28 of Set 10| nanga eboko
# Processing Record 29 of Set 10| goderich
# Processing Record 30 of Set 10| dordrecht
# Processing Record 31 of Set 10| katobu
# Processing Record 32 of Set 10| bonito
# Processing Record 33 of Set 10| andenes
# Processing Record 34 of Set 10| zaria
# Processing Record 35 of Set 10| bay city
# Processing Record 36 of Set 10| byron bay
# Processing Record 37 of Set 10| charagua
# Processing Record 38 of Set 10| port-cartier
# Processing Record 39 of Set 10| nikolayevka
# Processing Record 40 of Set 10| houma
# Processing Record 41 of Set 10| ossora
# Processing Record 42 of Set 10| kenai
# Processing Record 43 of Set 10| vynohradove
# Processing Record 44 of Set 10| lazaro cardenas
# Processing Record 45 of Set 10| moree
# Processing Record 46 of Set 10| pusad
# Processing Record 47 of Set 10| shubarshi
# Processing Record 48 of Set 10| nakamura
# Processing Record 49 of Set 10| beira
# Processing Record 0 of Set 11| mandera
# Processing Record 1 of Set 11| dingle
# Processing Record 2 of Set 11| bonavista
# Processing Record 3 of Set 11| jubayl
# jubaylnot found. Skipping...
# Processing Record 4 of Set 11| vestmanna
# Processing Record 5 of Set 11| ubatuba
# Processing Record 6 of Set 11| wamba
# Processing Record 7 of Set 11| laem sing
# Processing Record 8 of Set 11| brae
# Processing Record 9 of Set 11| yumen
# Processing Record 10 of Set 11| lar
# Processing Record 11 of Set 11| morondava
# Processing Record 12 of Set 11| olonets
# Processing Record 13 of Set 11| bargal
# bargalnot found. Skipping...
# Processing Record 14 of Set 11| lokosovo
# Processing Record 15 of Set 11| havre-saint-pierre
# Processing Record 16 of Set 11| kibungo
# Processing Record 17 of Set 11| pasighat
# Processing Record 18 of Set 11| gualeguay
# Processing Record 19 of Set 11| nouadhibou
# Processing Record 20 of Set 11| shieli
# Processing Record 21 of Set 11| batagay
# Processing Record 22 of Set 11| manavalakurichi
# Processing Record 23 of Set 11| mayumba
# Processing Record 24 of Set 11| borujan
# borujannot found. Skipping...
# Processing Record 25 of Set 11| road town
# Processing Record 26 of Set 11| swellendam
# Processing Record 27 of Set 11| sola
# Processing Record 28 of Set 11| bulaevo
# Processing Record 29 of Set 11| konskie
# Processing Record 30 of Set 11| dahanu
# Processing Record 31 of Set 11| riyadh
# Processing Record 32 of Set 11| launceston
# Processing Record 33 of Set 11| napier
# Processing Record 34 of Set 11| resistencia
# Processing Record 35 of Set 11| ilhabela
# Processing Record 36 of Set 11| ringe
# Processing Record 37 of Set 11| tambura
# Processing Record 38 of Set 11| sentyabrskiy
# sentyabrskiynot found. Skipping...
# Processing Record 39 of Set 11| khorixas
# Processing Record 40 of Set 11| boende
# Processing Record 41 of Set 11| caravelas
# Processing Record 42 of Set 11| fort nelson
# Processing Record 43 of Set 11| korhogo
# Processing Record 44 of Set 11| itupiranga
# Processing Record 45 of Set 11| cap malheureux
# Processing Record 46 of Set 11| stephenville
# Processing Record 47 of Set 11| gobabis
# Processing Record 48 of Set 11| usinsk
# Processing Record 49 of Set 11| gazanjyk
# Processing Record 0 of Set 12| changji
# Processing Record 1 of Set 12| adeje
# Processing Record 2 of Set 12| danane
# Processing Record 3 of Set 12| jiangyou
# Processing Record 4 of Set 12| vyritsa
# Processing Record 5 of Set 12| novopokrovka
# Processing Record 6 of Set 12| powell river
# Processing Record 7 of Set 12| onguday
# Processing Record 8 of Set 12| san patricio
# Processing Record 9 of Set 12| westport
# Processing Record 10 of Set 12| cidreira
# Processing Record 11 of Set 12| athni
# Processing Record 12 of Set 12| saint george
# Processing Record 13 of Set 12| constitucion
# Processing Record 14 of Set 12| kishapu
# Processing Record 15 of Set 12| zlotow
# Processing Record 16 of Set 12| urumqi
# Processing Record 17 of Set 12| kargil
# Processing Record 18 of Set 12| cockburn town
# Processing Record 19 of Set 12| tessalit
# Processing Record 20 of Set 12| tafresh
# Processing Record 21 of Set 12| port-gentil
# Processing Record 22 of Set 12| taraz
# Processing Record 23 of Set 12| tonantins
# Processing Record 24 of Set 12| traverse city
# Processing Record 25 of Set 12| tabas
# Processing Record 26 of Set 12| cayhagan
# Processing Record 27 of Set 12| oyama
# Processing Record 28 of Set 12| komatipoort
# Processing Record 29 of Set 12| port hardy
# Processing Record 30 of Set 12| karauzyak
# karauzyaknot found. Skipping...
# Processing Record 31 of Set 12| bukama
# Processing Record 32 of Set 12| hofn
# Processing Record 33 of Set 12| belyy yar
# Processing Record 34 of Set 12| komsomolskiy
# Processing Record 35 of Set 12| cabedelo
# Processing Record 36 of Set 12| bowen
# Processing Record 37 of Set 12| gashua
# Processing Record 38 of Set 12| rossano
# Processing Record 39 of Set 12| hay river
# Processing Record 40 of Set 12| tumannyy
# tumannyynot found. Skipping...
# Processing Record 41 of Set 12| astros
# Processing Record 42 of Set 12| shenjiamen
# Processing Record 43 of Set 12| nizhniy kuranakh
# Processing Record 44 of Set 12| wasilla
# Processing Record 45 of Set 12| puro
# Processing Record 46 of Set 12| polyarnyy
# Processing Record 47 of Set 12| liverpool
# Processing Record 48 of Set 12| tahoua
# Processing Record 49 of Set 12| jumla
# Processing Record 0 of Set 13| guadalupe y calvo
# Processing Record 1 of Set 13| kamiiso
# Processing Record 2 of Set 13| hami
# Processing Record 3 of Set 13| bontang
# Processing Record 4 of Set 13| moyale
# Processing Record 5 of Set 13| dauphin
# Processing Record 6 of Set 13| turbat
# Processing Record 7 of Set 13| matamoros
# Processing Record 8 of Set 13| nahavand
# Processing Record 9 of Set 13| ulaangom
# Processing Record 10 of Set 13| boquete
# Processing Record 11 of Set 13| benalla
# Processing Record 12 of Set 13| casian
# Processing Record 13 of Set 13| jiexiu
# Processing Record 14 of Set 13| emerald
# Processing Record 15 of Set 13| sokone
# Processing Record 16 of Set 13| sakaiminato
# Processing Record 17 of Set 13| lubin
# Processing Record 18 of Set 13| tena
# Processing Record 19 of Set 13| nokaneng
# Processing Record 20 of Set 13| bara
# Processing Record 21 of Set 13| katsuura
# Processing Record 22 of Set 13| drexel heights
# Processing Record 23 of Set 13| la rioja
# Processing Record 24 of Set 13| lima
# Processing Record 25 of Set 13| gornopravdinsk
# Processing Record 26 of Set 13| sorong
# Processing Record 27 of Set 13| senno
# Processing Record 28 of Set 13| talnakh

# %%
#city_holder
# Out:
# [{'City': 'port blair',
#   'Cloudiness': 90,
#   'Country': 'IN',
#   'Date': 1586670507,
#   'Humidity': 70,
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 302.1,
#   'Wind Speed': 2.14},
#  {'City': 'ushuaia',
#   'Cloudiness': 40,
#   'Country': 'AR',
#   'Date': 1586670284,
#   'Humidity': 64,
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 277.15,
#   'Wind Speed': 4.1},
#  {'City': 'vaini',
#   'Cloudiness': 40,
#   'Country': 'TO',
#   'Date': 1586670508,
#   'Humidity': 74,
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 299.15,
#   'Wind Speed': 2.6},
#  {'City': 'portland',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1586670387,
#   'Humidity': 57,
#   'Lat': 45.52,
#   'Lng': -122.68,
#   'Max Temp': 285.15,
#   'Wind Speed': 3.1},
#  {'City': 'xinxiang',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1586670509,
#   'Humidity': 18,
#   'Lat': 35.31,
#   'Lng': 113.87,
#   'Max Temp': 296.09,
#   'Wind Speed': 6.32},
#  {'City': 'pangnirtung',
#   'Cloudiness': 100,
#   'Country': 'CA',
#   'Date': 1586670509,
#   'Humidity': 89,
#   'Lat': 66.15,
#   'Lng': -65.71,
#   'Max Temp': 268.88,
#   'Wind Speed': 4.21},
#  {'City': 'novyy urengoy',
#   'Cloudiness': 99,
#   'Country': 'RU',
#   'Date': 1586670509,
#   'Humidity': 95,
#   'Lat': 66.08,
#   'Lng': 76.63,
#   'Max Temp': 267.15,
#   'Wind Speed': 3.13},
#  {'City': 'rayevskiy',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1586670510,
#   'Humidity': 58,
#   'Lat': 54.07,
#   'Lng': 54.95,
#   'Max Temp': 281.82,
#   'Wind Speed': 5.28},
#  {'City': 'mar del plata',
#   'Cloudiness': 100,
#   'Country': 'AR',
#   'Date': 1586670331,
#   'Humidity': 93,
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 287.59,
#   'Wind Speed': 1.5},
#  {'City': 'hasaki',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1586670511,
#   'Humidity': 66,
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 288.15,
#   'Wind Speed': 5.7},
#  {'City': 'tautira',
#   'Cloudiness': 100,
#   'Country': 'PF',
#   'Date': 1586670512,
#   'Humidity': 74,
#   'Lat': -17.73,
#   'Lng': -149.15,
#   'Max Temp': 301.15,
#   'Wind Speed': 1},
#  {'City': 'te anau',
#   'Cloudiness': 83,
#   'Country': 'NZ',
#   'Date': 1586670512,
#   'Humidity': 83,
#   'Lat': -45.42,
#   'Lng': 167.72,
#   'Max Temp': 285.37,
#   'Wind Speed': 0.46},
#  {'City': 'banepa',
#   'Cloudiness': 20,
#   'Country': 'NP',
#   'Date': 1586670513,
#   'Humidity': 46,
#   'Lat': 27.63,
#   'Lng': 85.52,
#   'Max Temp': 296.15,
#   'Wind Speed': 1},
#  {'City': 'hithadhoo',
#   'Cloudiness': 9,
#   'Country': 'MV',
#   'Date': 1586670513,
#   'Humidity': 68,
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 302.45,
#   'Wind Speed': 3.83},
#  {'City': 'kawalu',
#   'Cloudiness': 46,
#   'Country': 'ID',
#   'Date': 1586670513,
#   'Humidity': 50,
#   'Lat': -7.38,
#   'Lng': 108.21,
#   'Max Temp': 304.25,
#   'Wind Speed': 2.13},
#  {'City': 'faya',
#   'Cloudiness': 64,
#   'Country': 'SA',
#   'Date': 1586670514,
#   'Humidity': 82,
#   'Lat': 18.39,
#   'Lng': 42.45,
#   'Max Temp': 292.15,
#   'Wind Speed': 3.6},
#  {'City': 'new norfolk',
#   'Cloudiness': 75,
#   'Country': 'AU',
#   'Date': 1586670514,
#   'Humidity': 59,
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 289.15,
#   'Wind Speed': 6.7},
#  {'City': 'kananga',
#   'Cloudiness': 100,
#   'Country': 'CD',
#   'Date': 1586670515,
#   'Humidity': 78,
#   'Lat': -5.9,
#   'Lng': 22.42,
#   'Max Temp': 295.92,
#   'Wind Speed': 1.42},
#  {'City': 'albany',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1586670312,
#   'Humidity': 59,
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 274.15,
#   'Wind Speed': 1.49},
#  {'City': 'rikitea',
#   'Cloudiness': 92,
#   'Country': 'PF',
#   'Date': 1586670515,
#   'Humidity': 80,
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 299.01,
#   'Wind Speed': 4.09},
#  {'City': 'hobart',
#   'Cloudiness': 75,
#   'Country': 'AU',
#   'Date': 1586670346,
#   'Humidity': 59,
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 289.15,
#   'Wind Speed': 6.7},
#  {'City': 'cape town',
#   'Cloudiness': 75,
#   'Country': 'ZA',
#   'Date': 1586670223,
#   'Humidity': 93,
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 290.37,
#   'Wind Speed': 6.7},
#  {'City': 'bakel',
#   'Cloudiness': 31,
#   'Country': 'SN',
#   'Date': 1586670516,
#   'Humidity': 23,
#   'Lat': 14.9,
#   'Lng': -12.46,
#   'Max Temp': 300.14,
#   'Wind Speed': 5.36},
#  {'City': 'bay roberts',
#   'Cloudiness': 40,
#   'Country': 'CA',
#   'Date': 1586670517,
#   'Humidity': 95,
#   'Lat': 47.6,
#   'Lng': -53.26,
#   'Max Temp': 274.26,
#   'Wind Speed': 7.7},
#  {'City': 'bonthe',
#   'Cloudiness': 24,
#   'Country': 'SL',
#   'Date': 1586670517,
#   'Humidity': 85,
#   'Lat': 7.53,
#   'Lng': -12.51,
#   'Max Temp': 299.45,
#   'Wind Speed': 0.51},
#  {'City': 'butaritari',
#   'Cloudiness': 99,
#   'Country': 'KI',
#   'Date': 1586670518,
#   'Humidity': 77,
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 301.5,
#   'Wind Speed': 5.78},
#  {'City': 'yellowknife',
#   'Cloudiness': 5,
#   'Country': 'CA',
#   'Date': 1586670225,
#   'Humidity': 55,
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 260.15,
#   'Wind Speed': 1.5},
#  {'City': 'sturgeon falls',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1586670518,
#   'Humidity': 74,
#   'Lat': 46.36,
#   'Lng': -79.93,
#   'Max Temp': 273.71,
#   'Wind Speed': 3.1},
#  {'City': 'lagoa',
#   'Cloudiness': 4,
#   'Country': 'PT',
#   'Date': 1586670519,
#   'Humidity': 79,
#   'Lat': 39.05,
#   'Lng': -27.98,
#   'Max Temp': 289.07,
#   'Wind Speed': 3.55},
#  {'City': 'bluff',
#   'Cloudiness': 47,
#   'Country': 'NZ',
#   'Date': 1586670519,
#   'Humidity': 58,
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 293.15,
#   'Wind Speed': 0.89},
#  {'City': 'punta arenas',
#   'Cloudiness': 75,
#   'Country': 'CL',
#   'Date': 1586670520,
#   'Humidity': 93,
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 278.15,
#   'Wind Speed': 4.6},
#  {'City': 'castro',
#   'Cloudiness': 61,
#   'Country': 'BR',
#   'Date': 1586670249,
#   'Humidity': 69,
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 286.31,
#   'Wind Speed': 2.45},
#  {'City': 'kapaa',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1586670521,
#   'Humidity': 73,
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 297.15,
#   'Wind Speed': 2.1},
#  {'City': 'souillac',
#   'Cloudiness': 40,
#   'Country': 'MU',
#   'Date': 1586670522,
#   'Humidity': 65,
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 301.48,
#   'Wind Speed': 8.2},
#  {'City': 'torbay',
#   'Cloudiness': 40,
#   'Country': 'CA',
#   'Date': 1586670522,
#   'Humidity': 95,
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 274.26,
#   'Wind Speed': 7.7},
#  {'City': 'dongsheng',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1586670522,
#   'Humidity': 18,
#   'Lat': 39.82,
#   'Lng': 109.98,
#   'Max Temp': 284.05,
#   'Wind Speed': 2.82},
#  {'City': 'jamestown',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1586670523,
#   'Humidity': 59,
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 280.37,
#   'Wind Speed': 2.6},
#  {'City': 'new port richey',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1586670523,
#   'Humidity': 83,
#   'Lat': 28.24,
#   'Lng': -82.72,
#   'Max Temp': 298.15,
#   'Wind Speed': 4.6},
#  {'City': 'buraydah',
#   'Cloudiness': 4,
#   'Country': 'SA',
#   'Date': 1586670365,
#   'Humidity': 42,
#   'Lat': 26.33,
#   'Lng': 43.98,
#   'Max Temp': 292.15,
#   'Wind Speed': 6.7},
#  {'City': 'kahului',
#   'Cloudiness': 40,
#   'Country': 'US',
#   'Date': 1586670420,
#   'Humidity': 65,
#   'Lat': 20.89,
#   'Lng': -156.47,
#   'Max Temp': 299.15,
#   'Wind Speed': 3.1},
#  {'City': 'evensk',
#   'Cloudiness': 99,
#   'Country': 'RU',
#   'Date': 1586670524,
#   'Humidity': 92,
#   'Lat': 61.95,
#   'Lng': 159.23,
#   'Max Temp': 264.57,
#   'Wind Speed': 0.75},
#  {'City': 'ormara',
#   'Cloudiness': 56,
#   'Country': 'PK',
#   'Date': 1586670525,
#   'Humidity': 43,
#   'Lat': 25.21,
#   'Lng': 64.64,
#   'Max Temp': 302.06,
#   'Wind Speed': 2.42},
#  {'City': 'krasnoselkup',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1586670525,
#   'Humidity': 97,
#   'Lat': 65.7,
#   'Lng': 82.47,
#   'Max Temp': 273.36,
#   'Wind Speed': 2.92},
#  {'City': 'banda aceh',
#   'Cloudiness': 68,
#   'Country': 'ID',
#   'Date': 1586670525,
#   'Humidity': 62,
#   'Lat': 5.56,
#   'Lng': 95.32,
#   'Max Temp': 304.49,
#   'Wind Speed': 2.36},
#  {'City': 'shingu',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1586670526,
#   'Humidity': 81,
#   'Lat': 33.73,
#   'Lng': 135.98,
#   'Max Temp': 284.15,
#   'Wind Speed': 2.6},
#  {'City': 'richards bay',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1586670526,
#   'Humidity': 75,
#   'Lat': -28.78,
#   'Lng': 32.04,
#   'Max Temp': 295.86,
#   'Wind Speed': 5.73},
#  {'City': 'fortuna',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1586670527,
#   'Humidity': 93,
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 283.71,
#   'Wind Speed': 3.6},
#  {'City': 'barrow',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1586670527,
#   'Humidity': 86,
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 271.15,
#   'Wind Speed': 8.2},
#  {'City': 'porosozero',
#   'Cloudiness': 11,
#   'Country': 'RU',
#   'Date': 1586670527,
#   'Humidity': 85,
#   'Lat': 62.72,
#   'Lng': 32.73,
#   'Max Temp': 272.94,
#   'Wind Speed': 2.78},
#  {'City': 'bethel',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1586670528,
#   'Humidity': 74,
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 278.15,
#   'Wind Speed': 0.38},
#  {'City': 'olafsvik',
#   'Cloudiness': 51,
#   'Country': 'IS',
#   'Date': 1586670528,
#   'Humidity': 89,
#   'Lat': 64.89,
#   'Lng': -23.71,
#   'Max Temp': 273.85,
#   'Wind Speed': 8.38},
#  {'City': 'pangody',
#   'Cloudiness': 99,
#   'Country': 'RU',
#   'Date': 1586670529,
#   'Humidity': 95,
#   'Lat': 65.85,
#   'Lng': 74.49,
#   'Max Temp': 267.14,
#   'Wind Speed': 2.94},
#  {'City': 'isla mujeres',
#   'Cloudiness': 40,
#   'Country': 'MX',
#   'Date': 1586670529,
#   'Humidity': 78,
#   'Lat': 21.23,
#   'Lng': -86.73,
#   'Max Temp': 300.15,
#   'Wind Speed': 5.7},
#  {'City': 'iqaluit',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1586670529,
#   'Humidity': 73,
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 268.15,
#   'Wind Speed': 5.7},
#  {'City': 'chuy',
#   'Cloudiness': 16,
#   'Country': 'UY',
#   'Date': 1586670530,
#   'Humidity': 83,
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 288.27,
#   'Wind Speed': 1.79},
#  {'City': 'sao joao da barra',
#   'Cloudiness': 100,
#   'Country': 'BR',
#   'Date': 1586670530,
#   'Humidity': 93,
#   'Lat': -21.64,
#   'Lng': -41.05,
#   'Max Temp': 294.08,
#   'Wind Speed': 4.65},
#  {'City': 'hovd',
#   'Cloudiness': 95,
#   'Country': 'MN',
#   'Date': 1586670531,
#   'Humidity': 26,
#   'Lat': 48.01,
#   'Lng': 91.64,
#   'Max Temp': 282.74,
#   'Wind Speed': 2.68},
#  {'City': 'ribeira grande',
#   'Cloudiness': 16,
#   'Country': 'PT',
#   'Date': 1586670531,
#   'Humidity': 75,
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 288.92,
#   'Wind Speed': 2.28},
#  {'City': 'wajima',
#   'Cloudiness': 90,
#   'Country': 'JP',
#   'Date': 1586670532,
#   'Humidity': 58,
#   'Lat': 37.4,
#   'Lng': 136.9,
#   'Max Temp': 284.15,
#   'Wind Speed': 5.7},
#  {'City': 'cabra',
#   'Cloudiness': 78,
#   'Country': 'ES',
#   'Date': 1586670533,
#   'Humidity': 87,
#   'Lat': 37.47,
#   'Lng': -4.44,
#   'Max Temp': 285.93,
#   'Wind Speed': 1},
#  {'City': 'clyde river',
#   'Cloudiness': 20,
#   'Country': 'CA',
#   'Date': 1586670533,
#   'Humidity': 91,
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 256.15,
#   'Wind Speed': 3.6},
#  {'City': 'east london',
#   'Cloudiness': 96,
#   'Country': 'ZA',
#   'Date': 1586670533,
#   'Humidity': 73,
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 295.15,
#   'Wind Speed': 2.1},
#  {'City': 'kruisfontein',
#   'Cloudiness': 99,
#   'Country': 'ZA',
#   'Date': 1586670534,
#   'Humidity': 41,
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 292.41,
#   'Wind Speed': 6.55},
#  {'City': 'clearlake',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1586670534,
#   'Humidity': 87,
#   'Lat': 38.96,
#   'Lng': -122.63,
#   'Max Temp': 284.82,
#   'Wind Speed': 2.6},
#  {'City': 'mount isa',
#   'Cloudiness': 13,
#   'Country': 'AU',
#   'Date': 1586670535,
#   'Humidity': 7,
#   'Lat': -20.73,
#   'Lng': 139.5,
#   'Max Temp': 306.15,
#   'Wind Speed': 4.1},
#  {'City': 'ancud',
#   'Cloudiness': 0,
#   'Country': 'CL',
#   'Date': 1586670535,
#   'Humidity': 100,
#   'Lat': -41.87,
#   'Lng': -73.82,
#   'Max Temp': 276.15,
#   'Wind Speed': 1.5},
#  {'City': 'qaanaaq',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': 1586670535,
#   'Humidity': 72,
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 262.16,
#   'Wind Speed': 2.66},
#  {'City': 'nuuk',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': 1586670536,
#   'Humidity': 93,
#   'Lat': 64.18,
#   'Lng': -51.72,
#   'Max Temp': 275.15,
#   'Wind Speed': 8.2},
#  {'City': 'honningsvag',
#   'Cloudiness': 100,
#   'Country': 'NO',
#   'Date': 1586670536,
#   'Humidity': 90,
#   'Lat': 70.98,
#   'Lng': 25.97,
#   'Max Temp': 272.2,
#   'Wind Speed': 5.16},
#  {'City': 'padmanabhapuram',
#   'Cloudiness': 20,
#   'Country': 'IN',
#   'Date': 1586670537,
#   'Humidity': 62,
#   'Lat': 8.23,
#   'Lng': 77.33,
#   'Max Temp': 305.15,
#   'Wind Speed': 3.1},
#  {'City': 'mantua',
#   'Cloudiness': 0,
#   'Country': 'IT',
#   'Date': 1586670537,
#   'Humidity': 66,
#   'Lat': 45.17,
#   'Lng': 10.78,
#   'Max Temp': 285.93,
#   'Wind Speed': 1.5},
#  {'City': 'faanui',
#   'Cloudiness': 53,
#   'Country': 'PF',
#   'Date': 1586670537,
#   'Humidity': 73,
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 301.2,
#   'Wind Speed': 5.69},
#  {'City': 'namibe',
#   'Cloudiness': 16,
#   'Country': 'AO',
#   'Date': 1586670538,
#   'Humidity': 66,
#   'Lat': -15.2,
#   'Lng': 12.15,
#   'Max Temp': 297.54,
#   'Wind Speed': 1.77},
#  {'City': 'ternate',
#   'Cloudiness': 25,
#   'Country': 'ID',
#   'Date': 1586670538,
#   'Humidity': 74,
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 302.11,
#   'Wind Speed': 3.22},
#  {'City': 'port alfred',
#   'Cloudiness': 33,
#   'Country': 'ZA',
#   'Date': 1586670539,
#   'Humidity': 64,
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 293.15,
#   'Wind Speed': 2.24},
#  {'City': 'buala',
#   'Cloudiness': 86,
#   'Country': 'SB',
#   'Date': 1586670539,
#   'Humidity': 73,
#   'Lat': -8.14,
#   'Lng': 159.59,
#   'Max Temp': 302.07,
#   'Wind Speed': 1.95},
#  {'City': 'zhangye',
#   'Cloudiness': 90,
#   'Country': 'CN',
#   'Date': 1586670540,
#   'Humidity': 11,
#   'Lat': 38.93,
#   'Lng': 100.45,
#   'Max Temp': 290.54,
#   'Wind Speed': 3.25},
#  {'City': 'kilindoni',
#   'Cloudiness': 99,
#   'Country': 'TZ',
#   'Date': 1586670541,
#   'Humidity': 83,
#   'Lat': -7.91,
#   'Lng': 39.67,
#   'Max Temp': 300.51,
#   'Wind Speed': 6.95},
#  {'City': 'okhotsk',
#   'Cloudiness': 77,
#   'Country': 'RU',
#   'Date': 1586670541,
#   'Humidity': 94,
#   'Lat': 59.38,
#   'Lng': 143.3,
#   'Max Temp': 271.89,
#   'Wind Speed': 4.07},
#  {'City': 'baruun-urt',
#   'Cloudiness': 0,
#   'Country': 'MN',
#   'Date': 1586670542,
#   'Humidity': 16,
#   'Lat': 46.68,
#   'Lng': 113.28,
#   'Max Temp': 289.41,
#   'Wind Speed': 5.35},
#  {'City': 'hermanus',
#   'Cloudiness': 70,
#   'Country': 'ZA',
#   'Date': 1586670542,
#   'Humidity': 69,
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 292.59,
#   'Wind Speed': 5.36},
#  {'City': 'bredasdorp',
#   'Cloudiness': 71,
#   'Country': 'ZA',
#   'Date': 1586670542,
#   'Humidity': 68,
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 292.59,
#   'Wind Speed': 11.3},
#  {'City': 'carutapera',
#   'Cloudiness': 99,
#   'Country': 'BR',
#   'Date': 1586670543,
#   'Humidity': 86,
#   'Lat': -1.2,
#   'Lng': -46.02,
#   'Max Temp': 299.41,
#   'Wind Speed': 2.14},
#  {'City': 'narsaq',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': 1586670543,
#   'Humidity': 30,
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 279.15,
#   'Wind Speed': 27.8},
#  {'City': 'nizhniy odes',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1586670544,
#   'Humidity': 92,
#   'Lat': 63.64,
#   'Lng': 54.86,
#   'Max Temp': 270.53,
#   'Wind Speed': 1.34},
#  {'City': 'tura',
#   'Cloudiness': 12,
#   'Country': 'IN',
#   'Date': 1586670431,
#   'Humidity': 19,
#   'Lat': 25.52,
#   'Lng': 90.22,
#   'Max Temp': 308.03,
#   'Wind Speed': 1.77},
#  {'City': 'hobyo',
#   'Cloudiness': 45,
#   'Country': 'SO',
#   'Date': 1586670544,
#   'Humidity': 63,
#   'Lat': 5.35,
#   'Lng': 48.53,
#   'Max Temp': 303.17,
#   'Wind Speed': 4.91},
#  {'City': 'sinop',
#   'Cloudiness': 5,
#   'Country': 'TR',
#   'Date': 1586670545,
#   'Humidity': 47,
#   'Lat': 41.77,
#   'Lng': 34.87,
#   'Max Temp': 279.79,
#   'Wind Speed': 1.48},
#  {'City': 'camacha',
#   'Cloudiness': 75,
#   'Country': 'PT',
#   'Date': 1586670546,
#   'Humidity': 87,
#   'Lat': 33.08,
#   'Lng': -16.33,
#   'Max Temp': 289.15,
#   'Wind Speed': 8.2},
#  {'City': 'farmington',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1586670542,
#   'Humidity': 33,
#   'Lat': 36.73,
#   'Lng': -108.22,
#   'Max Temp': 281.15,
#   'Wind Speed': 3.1},
#  {'City': 'ostersund',
#   'Cloudiness': 100,
#   'Country': 'SE',
#   'Date': 1586670546,
#   'Humidity': 78,
#   'Lat': 63.18,
#   'Lng': 14.64,
#   'Max Temp': 275.15,
#   'Wind Speed': 5.1},
#  {'City': 'bhola',
#   'Cloudiness': 0,
#   'Country': 'BD',
#   'Date': 1586670547,
#   'Humidity': 33,
#   'Lat': 22.68,
#   'Lng': 90.65,
#   'Max Temp': 307.23,
#   'Wind Speed': 3.12},
#  {'City': 'champerico',
#   'Cloudiness': 35,
#   'Country': 'GT',
#   'Date': 1586670547,
#   'Humidity': 74,
#   'Lat': 14.3,
#   'Lng': -91.92,
#   'Max Temp': 300.85,
#   'Wind Speed': 2.03},
#  {'City': 'zhanaozen',
#   'Cloudiness': 0,
#   'Country': 'KZ',
#   'Date': 1586670548,
#   'Humidity': 50,
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Max Temp': 284.51,
#   'Wind Speed': 6.38},
#  {'City': 'airai',
#   'Cloudiness': 99,
#   'Country': 'TL',
#   'Date': 1586670548,
#   'Humidity': 69,
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 292.32,
#   'Wind Speed': 1.6},
#  {'City': 'port elizabeth',
#   'Cloudiness': 20,
#   'Country': 'ZA',
#   'Date': 1586670458,
#   'Humidity': 49,
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 294.15,
#   'Wind Speed': 7.7},
#  {'City': 'sioux lookout',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1586670549,
#   'Humidity': 74,
#   'Lat': 50.1,
#   'Lng': -91.92,
#   'Max Temp': 271.15,
#   'Wind Speed': 4.1},
#  {'City': 'tuktoyaktuk',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1586670550,
#   'Humidity': 71,
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 258.15,
#   'Wind Speed': 4.6},
#  {'City': 'aykhal',
#   'Cloudiness': 11,
#   'Country': 'RU',
#   'Date': 1586670550,
#   'Humidity': 47,
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 274.15,
#   'Wind Speed': 5},
#  {'City': 'atuona',
#   'Cloudiness': 26,
#   'Country': 'PF',
#   'Date': 1586670550,
#   'Humidity': 70,
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 301.08,
#   'Wind Speed': 3.43},
#  {'City': 'saint-philippe',
#   'Cloudiness': 75,
#   'Country': 'RE',
#   'Date': 1586670551,
#   'Humidity': 74,
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 300.93,
#   'Wind Speed': 7.2},
#  {'City': 'cukai',
#   'Cloudiness': 40,
#   'Country': 'MY',
#   'Date': 1586670551,
#   'Humidity': 70,
#   'Lat': 4.25,
#   'Lng': 103.42,
#   'Max Temp': 306.15,
#   'Wind Speed': 3.6},
#  {'City': 'kholtoson',
#   'Cloudiness': 94,
#   'Country': 'RU',
#   'Date': 1586670552,
#   'Humidity': 24,
#   'Lat': 50.3,
#   'Lng': 103.31,
#   'Max Temp': 285.29,
#   'Wind Speed': 2.26},
#  {'City': 'port hedland',
#   'Cloudiness': 40,
#   'Country': 'AU',
#   'Date': 1586670552,
#   'Humidity': 44,
#   'Lat': -20.32,
#   'Lng': 118.57,
#   'Max Temp': 307.15,
#   'Wind Speed': 8.2},
#  {'City': 'basco',
#   'Cloudiness': 87,
#   'Country': 'PH',
#   'Date': 1586670553,
#   'Humidity': 86,
#   'Lat': 20.45,
#   'Lng': 121.97,
#   'Max Temp': 296.51,
#   'Wind Speed': 11.88},
#  {'City': 'mataura',
#   'Cloudiness': 38,
#   'Country': 'NZ',
#   'Date': 1586670553,
#   'Humidity': 58,
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 293.15,
#   'Wind Speed': 0.89},
#  {'City': 'vila velha',
#   'Cloudiness': 75,
#   'Country': 'BR',
#   'Date': 1586670365,
#   'Humidity': 88,
#   'Lat': -20.33,
#   'Lng': -40.29,
#   'Max Temp': 296.48,
#   'Wind Speed': 4.1},
#  {'City': 'tuatapere',
#   'Cloudiness': 44,
#   'Country': 'NZ',
#   'Date': 1586670554,
#   'Humidity': 58,
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 293.15,
#   'Wind Speed': 0.89},
#  {'City': 'college',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1586670555,
#   'Humidity': 91,
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': 279.15,
#   'Wind Speed': 0.38},
#  {'City': 'vohibinany',
#   'Cloudiness': 63,
#   'Country': 'MG',
#   'Date': 1586670556,
#   'Humidity': 67,
#   'Lat': -17.35,
#   'Lng': 49.03,
#   'Max Temp': 298.18,
#   'Wind Speed': 2.3},
#  {'City': 'mount gambier',
#   'Cloudiness': 90,
#   'Country': 'AU',
#   'Date': 1586670556,
#   'Humidity': 62,
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 287.15,
#   'Wind Speed': 5.1},
#  {'City': 'ferrol',
#   'Cloudiness': 75,
#   'Country': 'ES',
#   'Date': 1586670557,
#   'Humidity': 100,
#   'Lat': 43.48,
#   'Lng': -8.24,
#   'Max Temp': 285.93,
#   'Wind Speed': 1},
#  {'City': 'cleveland',
#   'Cloudiness': 40,
#   'Country': 'US',
#   'Date': 1586670557,
#   'Humidity': 49,
#   'Lat': 41.5,
#   'Lng': -81.7,
#   'Max Temp': 283.15,
#   'Wind Speed': 4.1},
#  {'City': 'vardo',
#   'Cloudiness': 74,
#   'Country': 'NO',
#   'Date': 1586670558,
#   'Humidity': 93,
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 270.99,
#   'Wind Speed': 6.19},
#  {'City': 'weligama',
#   'Cloudiness': 12,
#   'Country': 'LK',
#   'Date': 1586670558,
#   'Humidity': 54,
#   'Lat': 5.97,
#   'Lng': 80.42,
#   'Max Temp': 305.71,
#   'Wind Speed': 2.62},
#  {'City': 'busselton',
#   'Cloudiness': 67,
#   'Country': 'AU',
#   'Date': 1586670559,
#   'Humidity': 52,
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 298.15,
#   'Wind Speed': 6.26},
#  {'City': 'pevek',
#   'Cloudiness': 4,
#   'Country': 'RU',
#   'Date': 1586670559,
#   'Humidity': 91,
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 260.91,
#   'Wind Speed': 6.36},
#  {'City': 'tokur',
#   'Cloudiness': 29,
#   'Country': 'RU',
#   'Date': 1586670560,
#   'Humidity': 39,
#   'Lat': 53.13,
#   'Lng': 132.9,
#   'Max Temp': 281.43,
#   'Wind Speed': 0.92},
#  {'City': 'muros',
#   'Cloudiness': 20,
#   'Country': 'ES',
#   'Date': 1586670561,
#   'Humidity': 100,
#   'Lat': 42.78,
#   'Lng': -9.06,
#   'Max Temp': 285.93,
#   'Wind Speed': 2.67},
#  {'City': 'wenling',
#   'Cloudiness': 37,
#   'Country': 'CN',
#   'Date': 1586670561,
#   'Humidity': 48,
#   'Lat': 28.37,
#   'Lng': 121.36,
#   'Max Temp': 292.59,
#   'Wind Speed': 6.87},
#  {'City': 'derzhavinsk',
#   'Cloudiness': 64,
#   'Country': 'KZ',
#   'Date': 1586670562,
#   'Humidity': 40,
#   'Lat': 51.1,
#   'Lng': 66.32,
#   'Max Temp': 284.89,
#   'Wind Speed': 4.2},
#  {'City': 'lenger',
#   'Cloudiness': 90,
#   'Country': 'KZ',
#   'Date': 1586670562,
#   'Humidity': 93,
#   'Lat': 42.18,
#   'Lng': 69.88,
#   'Max Temp': 288.15,
#   'Wind Speed': 3},
#  {'City': 'longyearbyen',
#   'Cloudiness': 20,
#   'Country': 'SJ',
#   'Date': 1586670562,
#   'Humidity': 63,
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 252.15,
#   'Wind Speed': 1.5},
#  {'City': 'chokurdakh',
#   'Cloudiness': 98,
#   'Country': 'RU',
#   'Date': 1586670563,
#   'Humidity': 95,
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': 268.18,
#   'Wind Speed': 6.31},
#  {'City': 'madang',
#   'Cloudiness': 98,
#   'Country': 'PG',
#   'Date': 1586670563,
#   'Humidity': 68,
#   'Lat': -5.22,
#   'Lng': 145.8,
#   'Max Temp': 303.08,
#   'Wind Speed': 2.8},
#  {'City': 'kavieng',
#   'Cloudiness': 95,
#   'Country': 'PG',
#   'Date': 1586670564,
#   'Humidity': 67,
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 302.45,
#   'Wind Speed': 1.01},
#  {'City': 'sept-iles',
#   'Cloudiness': 20,
#   'Country': 'CA',
#   'Date': 1586670354,
#   'Humidity': 54,
#   'Lat': 50.2,
#   'Lng': -66.38,
#   'Max Temp': 272.04,
#   'Wind Speed': 3.1},
#  {'City': 'grand gaube',
#   'Cloudiness': 40,
#   'Country': 'MU',
#   'Date': 1586670564,
#   'Humidity': 65,
#   'Lat': -20.01,
#   'Lng': 57.66,
#   'Max Temp': 301.48,
#   'Wind Speed': 8.2},
#  {'City': 'chernyshevskiy',
#   'Cloudiness': 19,
#   'Country': 'RU',
#   'Date': 1586670565,
#   'Humidity': 72,
#   'Lat': 63.01,
#   'Lng': 112.47,
#   'Max Temp': 275.07,
#   'Wind Speed': 4.22},
#  {'City': 'choya',
#   'Cloudiness': 26,
#   'Country': 'RU',
#   'Date': 1586670566,
#   'Humidity': 67,
#   'Lat': 52.01,
#   'Lng': 86.55,
#   'Max Temp': 283.02,
#   'Wind Speed': 1.06},
#  {'City': 'abu dhabi',
#   'Cloudiness': 100,
#   'Country': 'AE',
#   'Date': 1586670303,
#   'Humidity': 27,
#   'Lat': 24.47,
#   'Lng': 54.37,
#   'Max Temp': 304.26,
#   'Wind Speed': 6.2},
#  {'City': 'valence',
#   'Cloudiness': 59,
#   'Country': 'ES',
#   'Date': 1586670543,
#   'Humidity': 76,
#   'Lat': 39.47,
#   'Lng': -0.38,
#   'Max Temp': 287.04,
#   'Wind Speed': 4.6},
#  {'City': 'buctzotz',
#   'Cloudiness': 0,
#   'Country': 'MX',
#   'Date': 1586670567,
#   'Humidity': 82,
#   'Lat': 21.2,
#   'Lng': -88.78,
#   'Max Temp': 297.71,
#   'Wind Speed': 6.36},
#  {'City': 'yerofey pavlovich',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1586670567,
#   'Humidity': 45,
#   'Lat': 53.97,
#   'Lng': 121.97,
#   'Max Temp': 285.52,
#   'Wind Speed': 1.03},
#  {'City': 'norman wells',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1586670568,
#   'Humidity': 49,
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 269.15,
#   'Wind Speed': 2.6},
#  {'City': 'arraial do cabo',
#   'Cloudiness': 47,
#   'Country': 'BR',
#   'Date': 1586670568,
#   'Humidity': 77,
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 295.2,
#   'Wind Speed': 2.87},
#  {'City': 'bail hongal',
#   'Cloudiness': 0,
#   'Country': 'IN',
#   'Date': 1586670569,
#   'Humidity': 33,
#   'Lat': 15.82,
#   'Lng': 74.87,
#   'Max Temp': 305.15,
#   'Wind Speed': 3.41},
#  {'City': 'huarmey',
#   'Cloudiness': 12,
#   'Country': 'PE',
#   'Date': 1586670569,
#   'Humidity': 75,
#   'Lat': -10.07,
#   'Lng': -78.15,
#   'Max Temp': 296.62,
#   'Wind Speed': 3.38},
#  {'City': 'nemuro',
#   'Cloudiness': 20,
#   'Country': 'JP',
#   'Date': 1586670569,
#   'Humidity': 55,
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 277.15,
#   'Wind Speed': 3.6},
#  {'City': 'puerto ayora',
#   'Cloudiness': 58,
#   'Country': 'EC',
#   'Date': 1586670570,
#   'Humidity': 89,
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 299.26,
#   'Wind Speed': 0.45},
#  {'City': 'shache',
#   'Cloudiness': 58,
#   'Country': 'CN',
#   'Date': 1586670570,
#   'Humidity': 10,
#   'Lat': 38.42,
#   'Lng': 77.24,
#   'Max Temp': 297.36,
#   'Wind Speed': 0.59},
#  {'City': 'carnarvon',
#   'Cloudiness': 24,
#   'Country': 'AU',
#   'Date': 1586670571,
#   'Humidity': 62,
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 303.15,
#   'Wind Speed': 8.2},
#  {'City': 'dikson',
#   'Cloudiness': 95,
#   'Country': 'RU',
#   'Date': 1586670571,
#   'Humidity': 96,
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 265.05,
#   'Wind Speed': 3.2},
#  {'City': 'vestmannaeyjar',
#   'Cloudiness': 100,
#   'Country': 'IS',
#   'Date': 1586670572,
#   'Humidity': 81,
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 278.23,
#   'Wind Speed': 6.42},
#  {'City': 'avarua',
#   'Cloudiness': 100,
#   'Country': 'CK',
#   'Date': 1586670572,
#   'Humidity': 94,
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 301.15,
#   'Wind Speed': 2.1},
#  {'City': 'korla',
#   'Cloudiness': 60,
#   'Country': 'CN',
#   'Date': 1586670573,
#   'Humidity': 12,
#   'Lat': 41.76,
#   'Lng': 86.15,
#   'Max Temp': 295.46,
#   'Wind Speed': 3.48},
#  {'City': 'toyooka',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1586670573,
#   'Humidity': 87,
#   'Lat': 35.53,
#   'Lng': 134.83,
#   'Max Temp': 281.15,
#   'Wind Speed': 2.1},
#  {'City': 'cabo san lucas',
#   'Cloudiness': 66,
#   'Country': 'MX',
#   'Date': 1586670314,
#   'Humidity': 70,
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 292.04,
#   'Wind Speed': 2.68},
#  {'City': 'srednekolymsk',
#   'Cloudiness': 50,
#   'Country': 'RU',
#   'Date': 1586670574,
#   'Humidity': 96,
#   'Lat': 67.45,
#   'Lng': 153.68,
#   'Max Temp': 272.91,
#   'Wind Speed': 4.19},
#  {'City': 'quatre cocos',
#   'Cloudiness': 40,
#   'Country': 'MU',
#   'Date': 1586670575,
#   'Humidity': 65,
#   'Lat': -20.21,
#   'Lng': 57.76,
#   'Max Temp': 301.48,
#   'Wind Speed': 8.2},
#  {'City': 'tokmak',
#   'Cloudiness': 0,
#   'Country': 'UA',
#   'Date': 1586670575,
#   'Humidity': 57,
#   'Lat': 47.25,
#   'Lng': 35.71,
#   'Max Temp': 280.12,
#   'Wind Speed': 5.24},
#  {'City': 'cozumel',
#   'Cloudiness': 40,
#   'Country': 'MX',
#   'Date': 1586670575,
#   'Humidity': 78,
#   'Lat': 20.51,
#   'Lng': -86.95,
#   'Max Temp': 300.15,
#   'Wind Speed': 5.7},
#  {'City': 'mocuba',
#   'Cloudiness': 23,
#   'Country': 'MZ',
#   'Date': 1586670576,
#   'Humidity': 71,
#   'Lat': -16.84,
#   'Lng': 36.99,
#   'Max Temp': 297.32,
#   'Wind Speed': 0.65},
#  {'City': 'isangel',
#   'Cloudiness': 27,
#   'Country': 'VU',
#   'Date': 1586670576,
#   'Humidity': 65,
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max Temp': 299.33,
#   'Wind Speed': 2.87},
#  {'City': 'shetpe',
#   'Cloudiness': 0,
#   'Country': 'KZ',
#   'Date': 1586670577,
#   'Humidity': 51,
#   'Lat': 44.17,
#   'Lng': 52.12,
#   'Max Temp': 281.95,
#   'Wind Speed': 7.58},
#  {'City': 'esperance',
#   'Cloudiness': 100,
#   'Country': 'AU',
#   'Date': 1586670577,
#   'Humidity': 45,
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 301.15,
#   'Wind Speed': 8.2},
#  {'City': 'neder vindinge',
#   'Cloudiness': 89,
#   'Country': 'DK',
#   'Date': 1586670578,
#   'Humidity': 66,
#   'Lat': 55.03,
#   'Lng': 11.88,
#   'Max Temp': 282.59,
#   'Wind Speed': 4.1},
#  {'City': 'sao filipe',
#   'Cloudiness': 55,
#   'Country': 'CV',
#   'Date': 1586670578,
#   'Humidity': 76,
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 296.56,
#   'Wind Speed': 3.77},
#  {'City': 'konstantinovka',
#   'Cloudiness': 1,
#   'Country': 'RU',
#   'Date': 1586670578,
#   'Humidity': 29,
#   'Lat': 49.62,
#   'Lng': 127.98,
#   'Max Temp': 289.96,
#   'Wind Speed': 3.43},
#  {'City': 'prainha',
#   'Cloudiness': 87,
#   'Country': 'BR',
#   'Date': 1586670579,
#   'Humidity': 98,
#   'Lat': -1.8,
#   'Lng': -53.48,
#   'Max Temp': 296.18,
#   'Wind Speed': 0.74},
#  {'City': 'porto novo',
#   'Cloudiness': 40,
#   'Country': 'BJ',
#   'Date': 1586670579,
#   'Humidity': 83,
#   'Lat': 6.5,
#   'Lng': 2.6,
#   'Max Temp': 301.15,
#   'Wind Speed': 2.6},
#  {'City': 'severo-kurilsk',
#   'Cloudiness': 74,
#   'Country': 'RU',
#   'Date': 1586670580,
#   'Humidity': 93,
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 273.16,
#   'Wind Speed': 3.27},
#  {'City': 'bolobo',
#   'Cloudiness': 100,
#   'Country': 'CD',
#   'Date': 1586670580,
#   'Humidity': 81,
#   'Lat': -2.17,
#   'Lng': 16.23,
#   'Max Temp': 296.87,
#   'Wind Speed': 3.42},
#  {'City': 'gazli',
#   'Cloudiness': 100,
#   'Country': 'UZ',
#   'Date': 1586670581,
#   'Humidity': 41,
#   'Lat': 40.13,
#   'Lng': 63.45,
#   'Max Temp': 293.63,
#   'Wind Speed': 1.81},
#  {'City': 'rio gallegos',
#   'Cloudiness': 84,
#   'Country': 'AR',
#   'Date': 1586670582,
#   'Humidity': 70,
#   'Lat': -51.62,
#   'Lng': -69.22,
#   'Max Temp': 281.15,
#   'Wind Speed': 4.6},
#  {'City': 'ambon',
#   'Cloudiness': 40,
#   'Country': 'ID',
#   'Date': 1586670582,
#   'Humidity': 94,
#   'Lat': -3.7,
#   'Lng': 128.18,
#   'Max Temp': 299.15,
#   'Wind Speed': 3.1},
#  {'City': 'zhezkazgan',
#   'Cloudiness': 90,
#   'Country': 'KZ',
#   'Date': 1586670583,
#   'Humidity': 50,
#   'Lat': 47.8,
#   'Lng': 67.71,
#   'Max Temp': 284.15,
#   'Wind Speed': 3},
#  {'City': 'alofi',
#   'Cloudiness': 76,
#   'Country': 'NU',
#   'Date': 1586670583,
#   'Humidity': 78,
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 299.15,
#   'Wind Speed': 4.1},
#  {'City': 'sevsk',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1586670584,
#   'Humidity': 64,
#   'Lat': 52.15,
#   'Lng': 34.49,
#   'Max Temp': 276.95,
#   'Wind Speed': 4.73},
#  {'City': 'chabahar',
#   'Cloudiness': 20,
#   'Country': 'IR',
#   'Date': 1586670584,
#   'Humidity': 69,
#   'Lat': 25.29,
#   'Lng': 60.64,
#   'Max Temp': 301.15,
#   'Wind Speed': 4.1},
#  {'City': 'tecpan',
#   'Cloudiness': 75,
#   'Country': 'GT',
#   'Date': 1586670585,
#   'Humidity': 93,
#   'Lat': 14.76,
#   'Lng': -90.99,
#   'Max Temp': 292.15,
#   'Wind Speed': 0.56},
#  {'City': 'nelson bay',
#   'Cloudiness': 9,
#   'Country': 'AU',
#   'Date': 1586670585,
#   'Humidity': 42,
#   'Lat': -32.72,
#   'Lng': 152.15,
#   'Max Temp': 295.93,
#   'Wind Speed': 4.1},
#  {'City': 'ugoofaaru',
#   'Cloudiness': 17,
#   'Country': 'MV',
#   'Date': 1586670523,
#   'Humidity': 68,
#   'Lat': 5.67,
#   'Lng': 73,
#   'Max Temp': 303.07,
#   'Wind Speed': 4.71},
#  {'City': 'lamu',
#   'Cloudiness': 100,
#   'Country': 'KE',
#   'Date': 1586670586,
#   'Humidity': 78,
#   'Lat': -2.27,
#   'Lng': 40.9,
#   'Max Temp': 301.29,
#   'Wind Speed': 3.12},
#  {'City': 'geraldton',
#   'Cloudiness': 28,
#   'Country': 'AU',
#   'Date': 1586670586,
#   'Humidity': 62,
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 302.15,
#   'Wind Speed': 6.7},
#  {'City': 'ituporanga',
#   'Cloudiness': 48,
#   'Country': 'BR',
#   'Date': 1586670587,
#   'Humidity': 97,
#   'Lat': -27.41,
#   'Lng': -49.6,
#   'Max Temp': 288.71,
#   'Wind Speed': 0.45},
#  {'City': 'tasiilaq',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': 1586670587,
#   'Humidity': 68,
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 269.15,
#   'Wind Speed': 6.7},
#  {'City': 'carlsbad',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1586670588,
#   'Humidity': 77,
#   'Lat': 33.16,
#   'Lng': -117.35,
#   'Max Temp': 289.26,
#   'Wind Speed': 2.6},
#  {'City': 'husavik',
#   'Cloudiness': 90,
#   'Country': 'IS',
#   'Date': 1586670588,
#   'Humidity': 68,
#   'Lat': 66.04,
#   'Lng': -17.34,
#   'Max Temp': 272.15,
#   'Wind Speed': 7.7},
#  {'City': 'leningradskiy',
#   'Cloudiness': 93,
#   'Country': 'RU',
#   'Date': 1586670589,
#   'Humidity': 90,
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': 264.2,
#   'Wind Speed': 2.23},
#  {'City': 'hongjiang',
#   'Cloudiness': 13,
#   'Country': 'CN',
#   'Date': 1586670589,
#   'Humidity': 44,
#   'Lat': 27.11,
#   'Lng': 110,
#   'Max Temp': 292.29,
#   'Wind Speed': 2.73},
#  {'City': 'guhagar',
#   'Cloudiness': 15,
#   'Country': 'IN',
#   'Date': 1586670589,
#   'Humidity': 48,
#   'Lat': 17.48,
#   'Lng': 73.19,
#   'Max Temp': 305.74,
#   'Wind Speed': 3.35},
#  {'City': 'vostok',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1586670590,
#   'Humidity': 36,
#   'Lat': 46.49,
#   'Lng': 135.88,
#   'Max Temp': 281.61,
#   'Wind Speed': 3.72},
#  {'City': 'palasa',
#   'Cloudiness': 0,
#   'Country': 'IN',
#   'Date': 1586670590,
#   'Humidity': 29,
#   'Lat': 18.77,
#   'Lng': 84.42,
#   'Max Temp': 308.22,
#   'Wind Speed': 2.64},
#  {'City': 'lebu',
#   'Cloudiness': 0,
#   'Country': 'CL',
#   'Date': 1586670591,
#   'Humidity': 79,
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 283.2,
#   'Wind Speed': 5.08},
#  {'City': 'ponta delgada',
#   'Cloudiness': 20,
#   'Country': 'PT',
#   'Date': 1586670591,
#   'Humidity': 82,
#   'Lat': 37.73,
#   'Lng': -25.67,
#   'Max Temp': 287.15,
#   'Wind Speed': 4.6},
#  {'City': 'batemans bay',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1586670592,
#   'Humidity': 52,
#   'Lat': -35.72,
#   'Lng': 150.18,
#   'Max Temp': 293.71,
#   'Wind Speed': 1.79},
#  {'City': 'sainte-marie',
#   'Cloudiness': 40,
#   'Country': 'RE',
#   'Date': 1586670592,
#   'Humidity': 78,
#   'Lat': -20.9,
#   'Lng': 55.55,
#   'Max Temp': 300.93,
#   'Wind Speed': 5.7},
#  {'City': 'kaitangata',
#   'Cloudiness': 91,
#   'Country': 'NZ',
#   'Date': 1586670593,
#   'Humidity': 75,
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 288.71,
#   'Wind Speed': 0.45},
#  {'City': 'lakselv',
#   'Cloudiness': 100,
#   'Country': 'NO',
#   'Date': 1586670593,
#   'Humidity': 68,
#   'Lat': 70.05,
#   'Lng': 24.97,
#   'Max Temp': 270.93,
#   'Wind Speed': 12.9},
#  {'City': 'qalyub',
#   'Cloudiness': 0,
#   'Country': 'EG',
#   'Date': 1586670593,
#   'Humidity': 82,
#   'Lat': 30.18,
#   'Lng': 31.21,
#   'Max Temp': 288.15,
#   'Wind Speed': 2.24},
#  {'City': 'ayr',
#   'Cloudiness': 75,
#   'Country': 'GB',
#   'Date': 1586670594,
#   'Humidity': 87,
#   'Lat': 55.46,
#   'Lng': -4.63,
#   'Max Temp': 281.48,
#   'Wind Speed': 1},
#  {'City': 'salalah',
#   'Cloudiness': 40,
#   'Country': 'OM',
#   'Date': 1586670594,
#   'Humidity': 70,
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 302.15,
#   'Wind Speed': 6.2},
#  {'City': 'nikolskoye',
#   'Cloudiness': 32,
#   'Country': 'RU',
#   'Date': 1586670595,
#   'Humidity': 80,
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 277.04,
#   'Wind Speed': 2},
#  {'City': 'takoradi',
#   'Cloudiness': 49,
#   'Country': 'GH',
#   'Date': 1586670595,
#   'Humidity': 86,
#   'Lat': 4.88,
#   'Lng': -1.76,
#   'Max Temp': 299.55,
#   'Wind Speed': 1.41},
#  {'City': 'osypenko',
#   'Cloudiness': 0,
#   'Country': 'UA',
#   'Date': 1586670595,
#   'Humidity': 53,
#   'Lat': 46.91,
#   'Lng': 36.83,
#   'Max Temp': 277.59,
#   'Wind Speed': 5.36},
#  {'City': 'san cristobal',
#   'Cloudiness': 68,
#   'Country': 'VE',
#   'Date': 1586670596,
#   'Humidity': 61,
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Max Temp': 293.02,
#   'Wind Speed': 1.08},
#  {'City': 'dong hoi',
#   'Cloudiness': 99,
#   'Country': 'VN',
#   'Date': 1586670515,
#   'Humidity': 90,
#   'Lat': 17.48,
#   'Lng': 106.6,
#   'Max Temp': 294.54,
#   'Wind Speed': 7.66},
#  {'City': 'lavrentiya',
#   'Cloudiness': 99,
#   'Country': 'RU',
#   'Date': 1586670597,
#   'Humidity': 98,
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 273.06,
#   'Wind Speed': 3.91},
#  {'City': 'maniitsoq',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': 1586670597,
#   'Humidity': 89,
#   'Lat': 65.42,
#   'Lng': -52.9,
#   'Max Temp': 276.49,
#   'Wind Speed': 5.4},
#  {'City': 'tiksi',
#   'Cloudiness': 84,
#   'Country': 'RU',
#   'Date': 1586670598,
#   'Humidity': 90,
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': 258.63,
#   'Wind Speed': 7.26},
#  {'City': 'jeremie',
#   'Cloudiness': 4,
#   'Country': 'HT',
#   'Date': 1586670598,
#   'Humidity': 72,
#   'Lat': 18.65,
#   'Lng': -74.12,
#   'Max Temp': 299.04,
#   'Wind Speed': 2.12},
#  {'City': 'cherskiy',
#   'Cloudiness': 71,
#   'Country': 'RU',
#   'Date': 1586670598,
#   'Humidity': 96,
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 268.72,
#   'Wind Speed': 6.3},
#  {'City': 'monrovia',
#   'Cloudiness': 47,
#   'Country': 'LR',
#   'Date': 1586670478,
#   'Humidity': 84,
#   'Lat': 6.3,
#   'Lng': -10.8,
#   'Max Temp': 299.48,
#   'Wind Speed': 0.85},
#  {'City': 'shirokiy',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1586670599,
#   'Humidity': 31,
#   'Lat': 49.76,
#   'Lng': 129.52,
#   'Max Temp': 289.29,
#   'Wind Speed': 3.81},
#  {'City': 'thompson',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1586670312,
#   'Humidity': 78,
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 262.15,
#   'Wind Speed': 5.1},
#  {'City': 'mahebourg',
#   'Cloudiness': 40,
#   'Country': 'MU',
#   'Date': 1586670600,
#   'Humidity': 65,
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 301.48,
#   'Wind Speed': 8.2},
#  {'City': 'jalu',
#   'Cloudiness': 0,
#   'Country': 'LY',
#   'Date': 1586670601,
#   'Humidity': 38,
#   'Lat': 29.03,
#   'Lng': 21.55,
#   'Max Temp': 289.94,
#   'Wind Speed': 0.76},
#  {'City': 'zhaoyuan',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1586670601,
#   'Humidity': 36,
#   'Lat': 37.36,
#   'Lng': 120.4,
#   'Max Temp': 286.79,
#   'Wind Speed': 8.47},
#  {'City': 'saskylakh',
#   'Cloudiness': 36,
#   'Country': 'RU',
#   'Date': 1586670602,
#   'Humidity': 92,
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 261.1,
#   'Wind Speed': 4.97},
#  {'City': 'labuan',
#   'Cloudiness': 75,
#   'Country': 'MY',
#   'Date': 1586670312,
#   'Humidity': 79,
#   'Lat': 5.28,
#   'Lng': 115.24,
#   'Max Temp': 305.15,
#   'Wind Speed': 1.5},
#  {'City': 'palana',
#   'Cloudiness': 34,
#   'Country': 'RU',
#   'Date': 1586670602,
#   'Humidity': 95,
#   'Lat': 59.12,
#   'Lng': 159.97,
#   'Max Temp': 266.3,
#   'Wind Speed': 2.81},
#  {'City': 'flinders',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1586670603,
#   'Humidity': 30,
#   'Lat': -34.58,
#   'Lng': 150.86,
#   'Max Temp': 294.82,
#   'Wind Speed': 2.6},
#  {'City': 'tarko-sale',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1586670603,
#   'Humidity': 99,
#   'Lat': 64.92,
#   'Lng': 77.78,
#   'Max Temp': 271.49,
#   'Wind Speed': 2.43},
#  {'City': 'aklavik',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1586670604,
#   'Humidity': 67,
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 265.15,
#   'Wind Speed': 2.6},
#  {'City': 'rawatsar',
#   'Cloudiness': 49,
#   'Country': 'IN',
#   'Date': 1586670604,
#   'Humidity': 19,
#   'Lat': 29.28,
#   'Lng': 74.38,
#   'Max Temp': 308.61,
#   'Wind Speed': 3.02},
#  {'City': 'petropavlovsk-kamchatskiy',
#   'Cloudiness': 40,
#   'Country': 'RU',
#   'Date': 1586670605,
#   'Humidity': 59,
#   'Lat': 53.05,
#   'Lng': 158.65,
#   'Max Temp': 276.15,
#   'Wind Speed': 6},
#  {'City': 'quchan',
#   'Cloudiness': 100,
#   'Country': 'IR',
#   'Date': 1586670417,
#   'Humidity': 56,
#   'Lat': 37.11,
#   'Lng': 58.51,
#   'Max Temp': 283.67,
#   'Wind Speed': 2.73},
#  {'City': 'otatitlan',
#   'Cloudiness': 68,
#   'Country': 'MX',
#   'Date': 1586670606,
#   'Humidity': 75,
#   'Lat': 18.2,
#   'Lng': -96.03,
#   'Max Temp': 299.07,
#   'Wind Speed': 0.74},
#  {'City': 'poum',
#   'Cloudiness': 71,
#   'Country': 'NC',
#   'Date': 1586670606,
#   'Humidity': 71,
#   'Lat': -20.23,
#   'Lng': 164.02,
#   'Max Temp': 299.83,
#   'Wind Speed': 4.33},
#  {'City': 'upernavik',
#   'Cloudiness': 97,
#   'Country': 'GL',
#   'Date': 1586670607,
#   'Humidity': 85,
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 267.1,
#   'Wind Speed': 1.85},
#  {'City': 'eureka',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1586670607,
#   'Humidity': 81,
#   'Lat': 40.8,
#   'Lng': -124.16,
#   'Max Temp': 283.71,
#   'Wind Speed': 2.1},
#  {'City': 'vila franca do campo',
#   'Cloudiness': 20,
#   'Country': 'PT',
#   'Date': 1586670608,
#   'Humidity': 82,
#   'Lat': 37.72,
#   'Lng': -25.43,
#   'Max Temp': 287.15,
#   'Wind Speed': 4.6},
#  {'City': 'dwarka',
#   'Cloudiness': 0,
#   'Country': 'IN',
#   'Date': 1586670608,
#   'Humidity': 72,
#   'Lat': 22.24,
#   'Lng': 68.97,
#   'Max Temp': 300.15,
#   'Wind Speed': 5.38},
#  {'City': 'ivanteyevka',
#   'Cloudiness': 31,
#   'Country': 'RU',
#   'Date': 1586670608,
#   'Humidity': 74,
#   'Lat': 55.97,
#   'Lng': 37.92,
#   'Max Temp': 275.15,
#   'Wind Speed': 4},
#  {'City': 'caucaia',
#   'Cloudiness': 20,
#   'Country': 'BR',
#   'Date': 1586670351,
#   'Humidity': 94,
#   'Lat': -3.74,
#   'Lng': -38.65,
#   'Max Temp': 299.82,
#   'Wind Speed': 2.1},
#  {'City': 'antofagasta',
#   'Cloudiness': 75,
#   'Country': 'CL',
#   'Date': 1586670609,
#   'Humidity': 77,
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 291.15,
#   'Wind Speed': 3.6},
#  {'City': 'safaga',
#   'Cloudiness': 32,
#   'Country': 'EG',
#   'Date': 1586670609,
#   'Humidity': 41,
#   'Lat': 26.73,
#   'Lng': 33.94,
#   'Max Temp': 294.08,
#   'Wind Speed': 7.26},
#  {'City': 'roma',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1586670401,
#   'Humidity': 79,
#   'Lat': 43.21,
#   'Lng': -75.46,
#   'Max Temp': 274.26,
#   'Wind Speed': 1.97},
#  {'City': 'pacific grove',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1586670610,
#   'Humidity': 76,
#   'Lat': 36.62,
#   'Lng': -121.92,
#   'Max Temp': 286.48,
#   'Wind Speed': 2.6},
#  {'City': 'kamenka',
#   'Cloudiness': 96,
#   'Country': 'RU',
#   'Date': 1586670611,
#   'Humidity': 79,
#   'Lat': 51.32,
#   'Lng': 42.77,
#   'Max Temp': 275.93,
#   'Wind Speed': 0.89},
#  {'City': 'valley',
#   'Cloudiness': 40,
#   'Country': 'US',
#   'Date': 1586670611,
#   'Humidity': 40,
#   'Lat': 45.13,
#   'Lng': -116.13,
#   'Max Temp': 274.15,
#   'Wind Speed': 3.1},
#  {'City': 'zdvinsk',
#   'Cloudiness': 23,
#   'Country': 'RU',
#   'Date': 1586670611,
#   'Humidity': 80,
#   'Lat': 54.7,
#   'Lng': 78.66,
#   'Max Temp': 277.01,
#   'Wind Speed': 3.7},
#  {'City': 'risaralda',
#   'Cloudiness': 99,
#   'Country': 'CO',
#   'Date': 1586670612,
#   'Humidity': 55,
#   'Lat': 5.17,
#   'Lng': -75.77,
#   'Max Temp': 289.29,
#   'Wind Speed': 0.44},
#  {'City': 'bilibino',
#   'Cloudiness': 91,
#   'Country': 'RU',
#   'Date': 1586670612,
#   'Humidity': 89,
#   'Lat': 68.05,
#   'Lng': 166.44,
#   'Max Temp': 265.14,
#   'Wind Speed': 1.36},
#  {'City': 'adrar',
#   'Cloudiness': 0,
#   'Country': 'MR',
#   'Date': 1586670613,
#   'Humidity': 22,
#   'Lat': 20.5,
#   'Lng': -10.07,
#   'Max Temp': 295.68,
#   'Wind Speed': 5.34},
#  {'City': 'san felipe',
#   'Cloudiness': 86,
#   'Country': 'VE',
#   'Date': 1586670614,
#   'Humidity': 77,
#   'Lat': 10.34,
#   'Lng': -68.74,
#   'Max Temp': 296.01,
#   'Wind Speed': 1.21},
#  {'City': 'zhuanghe',
#   'Cloudiness': 15,
#   'Country': 'CN',
#   'Date': 1586670614,
#   'Humidity': 42,
#   'Lat': 39.7,
#   'Lng': 122.99,
#   'Max Temp': 285.35,
#   'Wind Speed': 3.31},
#  {'City': 'xining',
#   'Cloudiness': 93,
#   'Country': 'CN',
#   'Date': 1586670614,
#   'Humidity': 13,
#   'Lat': 36.62,
#   'Lng': 101.77,
#   'Max Temp': 286.15,
#   'Wind Speed': 2.67},
#  {'City': 'bubaque',
#   'Cloudiness': 1,
#   'Country': 'GW',
#   'Date': 1586670615,
#   'Humidity': 73,
#   'Lat': 11.28,
#   'Lng': -15.83,
#   'Max Temp': 298.56,
#   'Wind Speed': 3.28},
#  {'City': 'asyut',
#   'Cloudiness': 0,
#   'Country': 'EG',
#   'Date': 1586670615,
#   'Humidity': 38,
#   'Lat': 27.18,
#   'Lng': 31.18,
#   'Max Temp': 292.67,
#   'Wind Speed': 4.14},
#  {'City': 'arlit',
#   'Cloudiness': 11,
#   'Country': 'NE',
#   'Date': 1586670616,
#   'Humidity': 14,
#   'Lat': 18.74,
#   'Lng': 7.39,
#   'Max Temp': 300.19,
#   'Wind Speed': 4.33},
#  {'City': 'henties bay',
#   'Cloudiness': 10,
#   'Country': 'NA',
#   'Date': 1586670616,
#   'Humidity': 90,
#   'Lat': -22.12,
#   'Lng': 14.28,
#   'Max Temp': 289.82,
#   'Wind Speed': 1.34},
#  {'City': 'tignere',
#   'Cloudiness': 89,
#   'Country': 'CM',
#   'Date': 1586670618,
#   'Humidity': 52,
#   'Lat': 7.37,
#   'Lng': 12.65,
#   'Max Temp': 291.92,
#   'Wind Speed': 1.06},
#  {'City': 'canmore',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1586670618,
#   'Humidity': 78,
#   'Lat': 51.08,
#   'Lng': -115.35,
#   'Max Temp': 264.82,
#   'Wind Speed': 3.1},
#  {'City': 'kloulklubed',
#   'Cloudiness': 75,
#   'Country': 'PW',
#   'Date': 1586670619,
#   'Humidity': 62,
#   'Lat': 7.04,
#   'Lng': 134.26,
#   'Max Temp': 305.15,
#   'Wind Speed': 4.1},
#  {'City': 'hamilton',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1586670437,
#   'Humidity': 93,
#   'Lat': 39.18,
#   'Lng': -84.53,
#   'Max Temp': 283.15,
#   'Wind Speed': 1.5},
#  {'City': 'auki',
#   'Cloudiness': 77,
#   'Country': 'SB',
#   'Date': 1586670620,
#   'Humidity': 72,
#   'Lat': -8.77,
#   'Lng': 160.7,
#   'Max Temp': 302.03,
#   'Wind Speed': 0.41},
#  {'City': 'broome',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1586670620,
#   'Humidity': 55,
#   'Lat': 42.25,
#   'Lng': -75.83,
#   'Max Temp': 274.26,
#   'Wind Speed': 1.5},
#  {'City': 'beringovskiy',
#   'Cloudiness': 99,
#   'Country': 'RU',
#   'Date': 1586670620,
#   'Humidity': 95,
#   'Lat': 63.05,
#   'Lng': 179.32,
#   'Max Temp': 262.84,
#   'Wind Speed': 4.09},
#  {'City': 'zhanakorgan',
#   'Cloudiness': 100,
#   'Country': 'KZ',
#   'Date': 1586670621,
#   'Humidity': 72,
#   'Lat': 43.91,
#   'Lng': 67.25,
#   'Max Temp': 289.46,
#   'Wind Speed': 4.03},
#  {'City': 'lianzhou',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1586670621,
#   'Humidity': 38,
#   'Lat': 24.78,
#   'Lng': 112.38,
#   'Max Temp': 291.92,
#   'Wind Speed': 5.16},
#  {'City': 'praia da vitoria',
#   'Cloudiness': 75,
#   'Country': 'PT',
#   'Date': 1586670622,
#   'Humidity': 87,
#   'Lat': 38.73,
#   'Lng': -27.07,
#   'Max Temp': 288.15,
#   'Wind Speed': 4.16},
#  {'City': 'georgetown',
#   'Cloudiness': 20,
#   'Country': 'MY',
#   'Date': 1586670622,
#   'Humidity': 66,
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 306.15,
#   'Wind Speed': 3.1},
#  {'City': 'melfi',
#   'Cloudiness': 40,
#   'Country': 'IT',
#   'Date': 1586670622,
#   'Humidity': 75,
#   'Lat': 41,
#   'Lng': 15.65,
#   'Max Temp': 280.15,
#   'Wind Speed': 3.1},
#  {'City': 'ketchikan',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1586670624,
#   'Humidity': 64,
#   'Lat': 55.34,
#   'Lng': -131.65,
#   'Max Temp': 280.15,
#   'Wind Speed': 5.1},
#  {'City': 'victoria',
#   'Cloudiness': 4,
#   'Country': 'HK',
#   'Date': 1586670325,
#   'Humidity': 40,
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 297.59,
#   'Wind Speed': 4.6},
#  {'City': 'robertsport',
#   'Cloudiness': 28,
#   'Country': 'LR',
#   'Date': 1586670624,
#   'Humidity': 84,
#   'Lat': 6.75,
#   'Lng': -11.37,
#   'Max Temp': 299.1,
#   'Wind Speed': 1.93},
#  {'City': 'vanimo',
#   'Cloudiness': 96,
#   'Country': 'PG',
#   'Date': 1586670625,
#   'Humidity': 82,
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Max Temp': 301.51,
#   'Wind Speed': 3.5},
#  {'City': 'grand baie',
#   'Cloudiness': 40,
#   'Country': 'MU',
#   'Date': 1586670625,
#   'Humidity': 65,
#   'Lat': -20.02,
#   'Lng': 57.58,
#   'Max Temp': 301.48,
#   'Wind Speed': 8.2},
#  {'City': 'omboue',
#   'Cloudiness': 98,
#   'Country': 'GA',
#   'Date': 1586670626,
#   'Humidity': 88,
#   'Lat': -1.57,
#   'Lng': 9.26,
#   'Max Temp': 298.21,
#   'Wind Speed': 4.86},
#  {'City': 'manicore',
#   'Cloudiness': 99,
#   'Country': 'BR',
#   'Date': 1586670626,
#   'Humidity': 97,
#   'Lat': -5.81,
#   'Lng': -61.3,
#   'Max Temp': 296.42,
#   'Wind Speed': 0.75},
#  {'City': 'santa cruz do sul',
#   'Cloudiness': 0,
#   'Country': 'BR',
#   'Date': 1586670626,
#   'Humidity': 92,
#   'Lat': -29.72,
#   'Lng': -52.43,
#   'Max Temp': 285.37,
#   'Wind Speed': 0.45},
#  {'City': 'smithers',
#   'Cloudiness': 1,
#   'Country': 'CA',
#   'Date': 1586670627,
#   'Humidity': 29,
#   'Lat': 54.78,
#   'Lng': -127.17,
#   'Max Temp': 276.15,
#   'Wind Speed': 0.53},
#  {'City': 'kurilsk',
#   'Cloudiness': 90,
#   'Country': 'RU',
#   'Date': 1586670627,
#   'Humidity': 93,
#   'Lat': 45.23,
#   'Lng': 147.88,
#   'Max Temp': 271.39,
#   'Wind Speed': 3.71},
#  {'City': 'bac lieu',
#   'Cloudiness': 22,
#   'Country': 'VN',
#   'Date': 1586670628,
#   'Humidity': 52,
#   'Lat': 9.29,
#   'Lng': 105.72,
#   'Max Temp': 305.33,
#   'Wind Speed': 4.87},
#  {'City': 'joshimath',
#   'Cloudiness': 11,
#   'Country': 'IN',
#   'Date': 1586670628,
#   'Humidity': 9,
#   'Lat': 30.57,
#   'Lng': 79.57,
#   'Max Temp': 295.18,
#   'Wind Speed': 2.54},
#  {'City': 'taoudenni',
#   'Cloudiness': 0,
#   'Country': 'ML',
#   'Date': 1586670628,
#   'Humidity': 18,
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 297.39,
#   'Wind Speed': 1.54},
#  {'City': 'wallenhorst',
#   'Cloudiness': 44,
#   'Country': 'DE',
#   'Date': 1586670629,
#   'Humidity': 75,
#   'Lat': 52.35,
#   'Lng': 8.02,
#   'Max Temp': 280.37,
#   'Wind Speed': 1},
#  {'City': 'poitiers',
# ...
#   'Max Temp': 294.32,
#   'Wind Speed': 0.7},
#  {'City': 'ringe',
#   'Cloudiness': 69,
#   'Country': 'DK',
#   'Date': 1586670728,
#   'Humidity': 61,
#   'Lat': 55.25,
#   'Lng': 10.47,
#   'Max Temp': 282.15,
#   'Wind Speed': 3.1},
#  {'City': 'tambura',
#   'Cloudiness': 99,
#   'Country': 'SS',
#   'Date': 1586670729,
#   'Humidity': 69,
#   'Lat': 5.6,
#   'Lng': 27.47,
#   'Max Temp': 297.51,
#   'Wind Speed': 0.6},
#  {'City': 'khorixas',
#   'Cloudiness': 0,
#   'Country': 'NA',
#   'Date': 1586670729,
#   'Humidity': 45,
#   'Lat': -20.37,
#   'Lng': 14.97,
#   'Max Temp': 296.17,
#   'Wind Speed': 2.78},
#  {'City': 'boende',
#   'Cloudiness': 98,
#   'Country': 'CD',
#   'Date': 1586670730,
#   'Humidity': 87,
#   'Lat': -0.22,
#   'Lng': 20.87,
#   'Max Temp': 296.06,
#   'Wind Speed': 1.55},
#  {'City': 'caravelas',
#   'Cloudiness': 2,
#   'Country': 'BR',
#   'Date': 1586670730,
#   'Humidity': 86,
#   'Lat': -17.71,
#   'Lng': -39.25,
#   'Max Temp': 298.37,
#   'Wind Speed': 1.75},
#  {'City': 'fort nelson',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1586670731,
#   'Humidity': 45,
#   'Lat': 58.81,
#   'Lng': -122.7,
#   'Max Temp': 270.15,
#   'Wind Speed': 1.25},
#  {'City': 'korhogo',
#   'Cloudiness': 80,
#   'Country': 'CI',
#   'Date': 1586670731,
#   'Humidity': 61,
#   'Lat': 9.45,
#   'Lng': -5.63,
#   'Max Temp': 298.22,
#   'Wind Speed': 1.64},
#  {'City': 'itupiranga',
#   'Cloudiness': 90,
#   'Country': 'BR',
#   'Date': 1586670731,
#   'Humidity': 100,
#   'Lat': -5.13,
#   'Lng': -49.33,
#   'Max Temp': 298.15,
#   'Wind Speed': 1.5},
#  {'City': 'cap malheureux',
#   'Cloudiness': 40,
#   'Country': 'MU',
#   'Date': 1586670732,
#   'Humidity': 65,
#   'Lat': -19.98,
#   'Lng': 57.61,
#   'Max Temp': 301.48,
#   'Wind Speed': 8.2},
#  {'City': 'stephenville',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1586670732,
#   'Humidity': 88,
#   'Lat': 32.22,
#   'Lng': -98.2,
#   'Max Temp': 295.37,
#   'Wind Speed': 3.6},
#  {'City': 'gobabis',
#   'Cloudiness': 36,
#   'Country': 'NA',
#   'Date': 1586670733,
#   'Humidity': 82,
#   'Lat': -22.45,
#   'Lng': 18.97,
#   'Max Temp': 288.15,
#   'Wind Speed': 1},
#  {'City': 'usinsk',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1586670733,
#   'Humidity': 94,
#   'Lat': 65.99,
#   'Lng': 57.53,
#   'Max Temp': 267.59,
#   'Wind Speed': 2.73},
#  {'City': 'gazanjyk',
#   'Cloudiness': 6,
#   'Country': 'TM',
#   'Date': 1586670733,
#   'Humidity': 45,
#   'Lat': 39.24,
#   'Lng': 55.52,
#   'Max Temp': 288.39,
#   'Wind Speed': 4.16},
#  {'City': 'changji',
#   'Cloudiness': 35,
#   'Country': 'CN',
#   'Date': 1586670734,
#   'Humidity': 29,
#   'Lat': 44.02,
#   'Lng': 87.32,
#   'Max Temp': 289.15,
#   'Wind Speed': 3},
#  {'City': 'adeje',
#   'Cloudiness': 75,
#   'Country': 'ES',
#   'Date': 1586670734,
#   'Humidity': 68,
#   'Lat': 28.12,
#   'Lng': -16.73,
#   'Max Temp': 292.15,
#   'Wind Speed': 4.6},
#  {'City': 'danane',
#   'Cloudiness': 30,
#   'Country': 'CI',
#   'Date': 1586670735,
#   'Humidity': 86,
#   'Lat': 7.26,
#   'Lng': -8.15,
#   'Max Temp': 294.51,
#   'Wind Speed': 0.7},
#  {'City': 'jiangyou',
#   'Cloudiness': 14,
#   'Country': 'CN',
#   'Date': 1586670735,
#   'Humidity': 26,
#   'Lat': 31.77,
#   'Lng': 104.72,
#   'Max Temp': 294.98,
#   'Wind Speed': 2.79},
#  {'City': 'vyritsa',
#   'Cloudiness': 49,
#   'Country': 'RU',
#   'Date': 1586670735,
#   'Humidity': 69,
#   'Lat': 59.41,
#   'Lng': 30.35,
#   'Max Temp': 276.15,
#   'Wind Speed': 3},
#  {'City': 'novopokrovka',
#   'Cloudiness': 0,
#   'Country': 'UA',
#   'Date': 1586670736,
#   'Humidity': 63,
#   'Lat': 49.84,
#   'Lng': 36.55,
#   'Max Temp': 277.7,
#   'Wind Speed': 6.05},
#  {'City': 'powell river',
#   'Cloudiness': 5,
#   'Country': 'CA',
#   'Date': 1586670736,
#   'Humidity': 31,
#   'Lat': 49.85,
#   'Lng': -124.54,
#   'Max Temp': 283.15,
#   'Wind Speed': 2.6},
#  {'City': 'onguday',
#   'Cloudiness': 19,
#   'Country': 'RU',
#   'Date': 1586670737,
#   'Humidity': 38,
#   'Lat': 50.75,
#   'Lng': 86.15,
#   'Max Temp': 282.79,
#   'Wind Speed': 1.11},
#  {'City': 'san patricio',
#   'Cloudiness': 23,
#   'Country': 'MX',
#   'Date': 1586670737,
#   'Humidity': 62,
#   'Lat': 19.22,
#   'Lng': -104.7,
#   'Max Temp': 296.76,
#   'Wind Speed': 3.43},
#  {'City': 'westport',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1586670545,
#   'Humidity': 59,
#   'Lat': 41.14,
#   'Lng': -73.36,
#   'Max Temp': 282.15,
#   'Wind Speed': 0.26},
#  {'City': 'cidreira',
#   'Cloudiness': 26,
#   'Country': 'BR',
#   'Date': 1586670738,
#   'Humidity': 75,
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 290.35,
#   'Wind Speed': 1.4},
#  {'City': 'athni',
#   'Cloudiness': 0,
#   'Country': 'IN',
#   'Date': 1586670739,
#   'Humidity': 15,
#   'Lat': 16.73,
#   'Lng': 75.07,
#   'Max Temp': 309.47,
#   'Wind Speed': 3.77},
#  {'City': 'saint george',
#   'Cloudiness': 20,
#   'Country': 'US',
#   'Date': 1586670739,
#   'Humidity': 44,
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 289.82,
#   'Wind Speed': 1.51},
#  {'City': 'constitucion',
#   'Cloudiness': 47,
#   'Country': 'CL',
#   'Date': 1586670739,
#   'Humidity': 77,
#   'Lat': -35.33,
#   'Lng': -72.42,
#   'Max Temp': 284.2,
#   'Wind Speed': 3.38},
#  {'City': 'kishapu',
#   'Cloudiness': 96,
#   'Country': 'TZ',
#   'Date': 1586670740,
#   'Humidity': 56,
#   'Lat': -3.62,
#   'Lng': 33.87,
#   'Max Temp': 294.54,
#   'Wind Speed': 4.26},
#  {'City': 'zlotow',
#   'Cloudiness': 25,
#   'Country': 'PL',
#   'Date': 1586670740,
#   'Humidity': 48,
#   'Lat': 53.36,
#   'Lng': 17.04,
#   'Max Temp': 280.37,
#   'Wind Speed': 2.1},
#  {'City': 'urumqi',
#   'Cloudiness': 33,
#   'Country': 'CN',
#   'Date': 1586670559,
#   'Humidity': 29,
#   'Lat': 43.8,
#   'Lng': 87.6,
#   'Max Temp': 289.15,
#   'Wind Speed': 3},
#  {'City': 'kargil',
#   'Cloudiness': 54,
#   'Country': 'IN',
#   'Date': 1586670741,
#   'Humidity': 16,
#   'Lat': 34.57,
#   'Lng': 76.1,
#   'Max Temp': 277.78,
#   'Wind Speed': 0.65},
#  {'City': 'cockburn town',
#   'Cloudiness': 0,
#   'Country': 'TC',
#   'Date': 1586670671,
#   'Humidity': 81,
#   'Lat': 21.46,
#   'Lng': -71.14,
#   'Max Temp': 299,
#   'Wind Speed': 6.39},
#  {'City': 'tessalit',
#   'Cloudiness': 0,
#   'Country': 'ML',
#   'Date': 1586670742,
#   'Humidity': 15,
#   'Lat': 20.2,
#   'Lng': 1.01,
#   'Max Temp': 298.03,
#   'Wind Speed': 2.63},
#  {'City': 'tafresh',
#   'Cloudiness': 20,
#   'Country': 'IR',
#   'Date': 1586670742,
#   'Humidity': 70,
#   'Lat': 34.69,
#   'Lng': 50.01,
#   'Max Temp': 282.15,
#   'Wind Speed': 4.1},
#  {'City': 'port-gentil',
#   'Cloudiness': 99,
#   'Country': 'GA',
#   'Date': 1586670743,
#   'Humidity': 83,
#   'Lat': -0.72,
#   'Lng': 8.78,
#   'Max Temp': 299.82,
#   'Wind Speed': 5.17},
#  {'City': 'taraz',
#   'Cloudiness': 90,
#   'Country': 'KZ',
#   'Date': 1586670686,
#   'Humidity': 87,
#   'Lat': 42.9,
#   'Lng': 71.37,
#   'Max Temp': 285.15,
#   'Wind Speed': 5},
#  {'City': 'tonantins',
#   'Cloudiness': 100,
#   'Country': 'BR',
#   'Date': 1586670744,
#   'Humidity': 97,
#   'Lat': -2.87,
#   'Lng': -67.8,
#   'Max Temp': 295.85,
#   'Wind Speed': 1.47},
#  {'City': 'traverse city',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1586670744,
#   'Humidity': 72,
#   'Lat': 44.76,
#   'Lng': -85.62,
#   'Max Temp': 282.15,
#   'Wind Speed': 2.6},
#  {'City': 'tabas',
#   'Cloudiness': 95,
#   'Country': 'IR',
#   'Date': 1586670744,
#   'Humidity': 64,
#   'Lat': 33.6,
#   'Lng': 56.92,
#   'Max Temp': 293.15,
#   'Wind Speed': 5.1},
#  {'City': 'cayhagan',
#   'Cloudiness': 2,
#   'Country': 'PH',
#   'Date': 1586670745,
#   'Humidity': 64,
#   'Lat': 9.67,
#   'Lng': 122.43,
#   'Max Temp': 301.77,
#   'Wind Speed': 3.24},
#  {'City': 'oyama',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1586670745,
#   'Humidity': 54,
#   'Lat': 36.3,
#   'Lng': 139.8,
#   'Max Temp': 289.82,
#   'Wind Speed': 4.6},
#  {'City': 'komatipoort',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1586670746,
#   'Humidity': 82,
#   'Lat': -25.43,
#   'Lng': 31.95,
#   'Max Temp': 292.59,
#   'Wind Speed': 0.5},
#  {'City': 'port hardy',
#   'Cloudiness': 5,
#   'Country': 'CA',
#   'Date': 1586670746,
#   'Humidity': 48,
#   'Lat': 50.7,
#   'Lng': -127.42,
#   'Max Temp': 279.15,
#   'Wind Speed': 3.6},
#  {'City': 'bukama',
#   'Cloudiness': 83,
#   'Country': 'CD',
#   'Date': 1586670747,
#   'Humidity': 70,
#   'Lat': -9.2,
#   'Lng': 25.85,
#   'Max Temp': 296.26,
#   'Wind Speed': 0.49},
#  {'City': 'hofn',
#   'Cloudiness': 14,
#   'Country': 'IS',
#   'Date': 1586670747,
#   'Humidity': 88,
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 271.08,
#   'Wind Speed': 7.38},
#  {'City': 'belyy yar',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1586670748,
#   'Humidity': 31,
#   'Lat': 53.6,
#   'Lng': 91.39,
#   'Max Temp': 283.15,
#   'Wind Speed': 3},
#  {'City': 'komsomolskiy',
#   'Cloudiness': 68,
#   'Country': 'UZ',
#   'Date': 1586670748,
#   'Humidity': 48,
#   'Lat': 40.43,
#   'Lng': 71.72,
#   'Max Temp': 291.15,
#   'Wind Speed': 2.1},
#  {'City': 'cabedelo',
#   'Cloudiness': 20,
#   'Country': 'BR',
#   'Date': 1586670749,
#   'Humidity': 94,
#   'Lat': -6.98,
#   'Lng': -34.83,
#   'Max Temp': 297.15,
#   'Wind Speed': 1},
#  {'City': 'bowen',
#   'Cloudiness': 22,
#   'Country': 'AU',
#   'Date': 1586670749,
#   'Humidity': 39,
#   'Lat': -20.02,
#   'Lng': 148.23,
#   'Max Temp': 308.15,
#   'Wind Speed': 3.1},
#  {'City': 'gashua',
#   'Cloudiness': 100,
#   'Country': 'NG',
#   'Date': 1586670749,
#   'Humidity': 16,
#   'Lat': 12.87,
#   'Lng': 11.05,
#   'Max Temp': 298.77,
#   'Wind Speed': 3.8},
#  {'City': 'rossano',
#   'Cloudiness': 0,
#   'Country': 'IT',
#   'Date': 1586670750,
#   'Humidity': 94,
#   'Lat': 39.58,
#   'Lng': 16.63,
#   'Max Temp': 283.71,
#   'Wind Speed': 0.15},
#  {'City': 'hay river',
#   'Cloudiness': 20,
#   'Country': 'CA',
#   'Date': 1586670750,
#   'Humidity': 66,
#   'Lat': 60.82,
#   'Lng': -115.8,
#   'Max Temp': 261.15,
#   'Wind Speed': 3.1},
#  {'City': 'astros',
#   'Cloudiness': 0,
#   'Country': 'GR',
#   'Date': 1586670751,
#   'Humidity': 53,
#   'Lat': 37.4,
#   'Lng': 22.73,
#   'Max Temp': 290.37,
#   'Wind Speed': 1.37},
#  {'City': 'shenjiamen',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1586670751,
#   'Humidity': 60,
#   'Lat': 29.96,
#   'Lng': 122.3,
#   'Max Temp': 286.66,
#   'Wind Speed': 13.2},
#  {'City': 'nizhniy kuranakh',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1586670752,
#   'Humidity': 64,
#   'Lat': 58.84,
#   'Lng': 125.49,
#   'Max Temp': 276.91,
#   'Wind Speed': 4.87},
#  {'City': 'wasilla',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1586670663,
#   'Humidity': 41,
#   'Lat': 61.58,
#   'Lng': -149.44,
#   'Max Temp': 277.15,
#   'Wind Speed': 1.5},
#  {'City': 'puro',
#   'Cloudiness': 5,
#   'Country': 'PH',
#   'Date': 1586670752,
#   'Humidity': 56,
#   'Lat': 12.48,
#   'Lng': 123.38,
#   'Max Temp': 304.26,
#   'Wind Speed': 1.51},
#  {'City': 'polyarnyy',
#   'Cloudiness': 74,
#   'Country': 'RU',
#   'Date': 1586670753,
#   'Humidity': 62,
#   'Lat': 69.2,
#   'Lng': 33.45,
#   'Max Temp': 269.15,
#   'Wind Speed': 3},
#  {'City': 'liverpool',
#   'Cloudiness': 94,
#   'Country': 'GB',
#   'Date': 1586670535,
#   'Humidity': 93,
#   'Lat': 53.41,
#   'Lng': -2.98,
#   'Max Temp': 284.26,
#   'Wind Speed': 0.5},
#  {'City': 'tahoua',
#   'Cloudiness': 2,
#   'Country': 'NE',
#   'Date': 1586670754,
#   'Humidity': 12,
#   'Lat': 14.89,
#   'Lng': 5.27,
#   'Max Temp': 302.15,
#   'Wind Speed': 4.1},
#  {'City': 'jumla',
#   'Cloudiness': 0,
#   'Country': 'NP',
#   'Date': 1586670754,
#   'Humidity': 87,
#   'Lat': 29.27,
#   'Lng': 82.18,
#   'Max Temp': 292.59,
#   'Wind Speed': 0.45},
#  {'City': 'guadalupe y calvo',
#   'Cloudiness': 0,
#   'Country': 'MX',
#   'Date': 1586670755,
#   'Humidity': 30,
#   'Lat': 26.1,
#   'Lng': -106.97,
#   'Max Temp': 275.27,
#   'Wind Speed': 1.96},
#  {'City': 'kamiiso',
#   'Cloudiness': 20,
#   'Country': 'JP',
#   'Date': 1586670755,
#   'Humidity': 66,
#   'Lat': 41.82,
#   'Lng': 140.65,
#   'Max Temp': 279.15,
#   'Wind Speed': 5.7},
#  {'City': 'hami',
#   'Cloudiness': 35,
#   'Country': 'CN',
#   'Date': 1586670755,
#   'Humidity': 11,
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 294.89,
#   'Wind Speed': 1.8},
#  {'City': 'bontang',
#   'Cloudiness': 9,
#   'Country': 'ID',
#   'Date': 1586670756,
#   'Humidity': 63,
#   'Lat': 0.13,
#   'Lng': 117.5,
#   'Max Temp': 302.94,
#   'Wind Speed': 3.62},
#  {'City': 'moyale',
#   'Cloudiness': 80,
#   'Country': 'KE',
#   'Date': 1586670756,
#   'Humidity': 63,
#   'Lat': 3.52,
#   'Lng': 39.06,
#   'Max Temp': 295.64,
#   'Wind Speed': 4.54},
#  {'City': 'dauphin',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1586670757,
#   'Humidity': 92,
#   'Lat': 51.15,
#   'Lng': -100.05,
#   'Max Temp': 268.15,
#   'Wind Speed': 3.1},
#  {'City': 'turbat',
#   'Cloudiness': 53,
#   'Country': 'PK',
#   'Date': 1586670757,
#   'Humidity': 24,
#   'Lat': 26,
#   'Lng': 63.04,
#   'Max Temp': 305.27,
#   'Wind Speed': 2.68},
#  {'City': 'matamoros',
#   'Cloudiness': 49,
#   'Country': 'MX',
#   'Date': 1586670669,
#   'Humidity': 14,
#   'Lat': 25.53,
#   'Lng': -103.25,
#   'Max Temp': 295.05,
#   'Wind Speed': 6.09},
#  {'City': 'nahavand',
#   'Cloudiness': 0,
#   'Country': 'IR',
#   'Date': 1586670758,
#   'Humidity': 25,
#   'Lat': 34.19,
#   'Lng': 48.38,
#   'Max Temp': 282.37,
#   'Wind Speed': 2.52},
#  {'City': 'ulaangom',
#   'Cloudiness': 100,
#   'Country': 'MN',
#   'Date': 1586670758,
#   'Humidity': 69,
#   'Lat': 49.98,
#   'Lng': 92.07,
#   'Max Temp': 273.27,
#   'Wind Speed': 0.59},
#  {'City': 'boquete',
#   'Cloudiness': 97,
#   'Country': 'PA',
#   'Date': 1586670759,
#   'Humidity': 73,
#   'Lat': 8.78,
#   'Lng': -82.43,
#   'Max Temp': 293.15,
#   'Wind Speed': 1.34},
#  {'City': 'benalla',
#   'Cloudiness': 40,
#   'Country': 'AU',
#   'Date': 1586670759,
#   'Humidity': 52,
#   'Lat': -36.55,
#   'Lng': 145.98,
#   'Max Temp': 291.15,
#   'Wind Speed': 3.6},
#  {'City': 'casian',
#   'Cloudiness': 15,
#   'Country': 'PH',
#   'Date': 1586670759,
#   'Humidity': 64,
#   'Lat': 11.04,
#   'Lng': 119.71,
#   'Max Temp': 302.24,
#   'Wind Speed': 2.42},
#  {'City': 'jiexiu',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1586670760,
#   'Humidity': 19,
#   'Lat': 37.02,
#   'Lng': 111.91,
#   'Max Temp': 289.95,
#   'Wind Speed': 4.4},
#  {'City': 'emerald',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1586670760,
#   'Humidity': 18,
#   'Lat': -23.53,
#   'Lng': 148.17,
#   'Max Temp': 305.15,
#   'Wind Speed': 6.2},
#  {'City': 'sokone',
#   'Cloudiness': 29,
#   'Country': 'SN',
#   'Date': 1586670760,
#   'Humidity': 70,
#   'Lat': 13.88,
#   'Lng': -16.37,
#   'Max Temp': 294.42,
#   'Wind Speed': 2.74},
#  {'City': 'sakaiminato',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1586670761,
#   'Humidity': 93,
#   'Lat': 35.55,
#   'Lng': 133.23,
#   'Max Temp': 281.15,
#   'Wind Speed': 10.3},
#  {'City': 'lubin',
#   'Cloudiness': 86,
#   'Country': 'PL',
#   'Date': 1586670761,
#   'Humidity': 61,
#   'Lat': 51.4,
#   'Lng': 16.2,
#   'Max Temp': 283.15,
#   'Wind Speed': 3.1},
#  {'City': 'tena',
#   'Cloudiness': 100,
#   'Country': 'EC',
#   'Date': 1586670762,
#   'Humidity': 67,
#   'Lat': -0.98,
#   'Lng': -77.82,
#   'Max Temp': 295.35,
#   'Wind Speed': 0.89},
#  {'City': 'nokaneng',
#   'Cloudiness': 48,
#   'Country': 'BW',
#   'Date': 1586670762,
#   'Humidity': 48,
#   'Lat': -19.67,
#   'Lng': 22.27,
#   'Max Temp': 295.28,
#   'Wind Speed': 1.3},
#  {'City': 'bara',
#   'Cloudiness': 100,
#   'Country': 'NG',
#   'Date': 1586670762,
#   'Humidity': 26,
#   'Lat': 10.37,
#   'Lng': 10.73,
#   'Max Temp': 300.21,
#   'Wind Speed': 1.96},
#  {'City': 'katsuura',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1586670763,
#   'Humidity': 67,
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 287.59,
#   'Wind Speed': 4.1},
#  {'City': 'drexel heights',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1586670763,
#   'Humidity': 71,
#   'Lat': 32.14,
#   'Lng': -111.03,
#   'Max Temp': 284.82,
#   'Wind Speed': 3.07},
#  {'City': 'la rioja',
#   'Cloudiness': 74,
#   'Country': 'ES',
#   'Date': 1586670764,
#   'Humidity': 93,
#   'Lat': 42.25,
#   'Lng': -2.5,
#   'Max Temp': 284.15,
#   'Wind Speed': 2.1},
#  {'City': 'lima',
#   'Cloudiness': 1,
#   'Country': 'PE',
#   'Date': 1586669888,
#   'Humidity': 88,
#   'Lat': -12.04,
#   'Lng': -77.03,
#   'Max Temp': 294.15,
#   'Wind Speed': 3.6},
#  {'City': 'gornopravdinsk',
#   'Cloudiness': 14,
#   'Country': 'RU',
#   'Date': 1586670765,
#   'Humidity': 76,
#   'Lat': 60.05,
#   'Lng': 69.9,
#   'Max Temp': 281.47,
#   'Wind Speed': 2.18},
#  {'City': 'sorong',
#   'Cloudiness': 40,
#   'Country': 'ID',
#   'Date': 1586670765,
#   'Humidity': 83,
#   'Lat': -0.88,
#   'Lng': 131.25,
#   'Max Temp': 301.9,
#   'Wind Speed': 2.02},
#  {'City': 'senno',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1586670766,
#   'Humidity': 76,
#   'Lat': 59.53,
#   'Lng': 33.92,
#   'Max Temp': 274.96,
#   'Wind Speed': 1.36},
#  {'City': 'talnakh',
#   'Cloudiness': 75,
#   'Country': 'RU',
#   'Date': 1586670766,
#   'Humidity': 85,
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': 265.15,
#   'Wind Speed': 15}]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
test_city = pd.DataFrame(city_holder)
test_city.head(10)
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     port blair          90      IN  1586670507        70  11.67   92.75
# 1        ushuaia          40      AR  1586670284        64 -54.80  -68.30
# 2          vaini          40      TO  1586670508        74 -21.20 -175.20
# 3       portland           1      US  1586670387        57  45.52 -122.68
# 4       xinxiang           0      CN  1586670509        18  35.31  113.87
# 5    pangnirtung         100      CA  1586670509        89  66.15  -65.71
# 6  novyy urengoy          99      RU  1586670509        95  66.08   76.63
# 7      rayevskiy         100      RU  1586670510        58  54.07   54.95
# 8  mar del plata         100      AR  1586670331        93 -38.00  -57.56
# 9         hasaki          75      JP  1586670511        66  35.73  140.83
#
#    Max Temp  Wind Speed
# 0    302.10        2.14
# 1    277.15        4.10
# 2    299.15        2.60
# 3    285.15        3.10
# 4    296.09        6.32
# 5    268.88        4.21
# 6    267.15        3.13
# 7    281.82        5.28
# 8    287.59        1.50
# 9    288.15        5.70

# %%
test_city.to_csv("RandomCities.csv")

# %%
from datetime import datetime
date = datetime.date(datetime.now())
print(date)
# Out:
# 2020-04-11

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# t_slope, t_int, t_r, t_p, t_std_err = stats.linregress(latitude, temp)
# t_fit = t_slope * latitude + t_int
#line_equation_t = "y = " + str(t_slope) + "x +" + str(t_int)


latitude = test_city.iloc[:,5]
temp = test_city.iloc[:,7]
t_slope, t_int, t_r, t_p, t_std_err = stats.linregress(latitude, temp)
t_fit = t_slope * latitude + t_int
plt.scatter(latitude, temp)
plt.plot(latitude,t_fit,"r")#label='y={:.2f}x+{:.2f}'.format(t_slope,t_int))
#plt.annotate(line_equation_t,(5,10),fontsize=5)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("City Latitude vs. Max Temperature " + str(date))
plt.grid()
#how to add current date
plt.savefig("City Latitude vs Max Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
latitude = test_city.iloc[:,5]
humidity = test_city.iloc[:,4]
plt.scatter(latitude, humidity)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("City Latitude vs. Humidity " + str(date))
#how to add current date
plt.grid()
plt.savefig("City Latitude vs Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
latitude = test_city.iloc[:,5]
cloudiness = test_city.iloc[:,1]
plt.scatter(latitude, cloudiness)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"City Latitude vs. Cloudiness {date}")
#how to add current date
plt.grid()
plt.savefig("City Latitude vs Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
latitude = test_city.iloc[:,5]
wind_speed = test_city.iloc[:,8]
plt.scatter(latitude, wind_speed)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.title(f"City Latitude vs. Wind Speed {date}")
#how to add current date
plt.grid()
plt.savefig("City Latitude vs Wind Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

#north(greater than or equal to 0 degrees latitude)
northern_hem = test_city.loc[(test_city["Lat"]>=0)]
northern_hem
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        port blair          90      IN  1586670507        70  11.67   92.75
# 3          portland           1      US  1586670387        57  45.52 -122.68
# 4          xinxiang           0      CN  1586670509        18  35.31  113.87
# 5       pangnirtung         100      CA  1586670509        89  66.15  -65.71
# 6     novyy urengoy          99      RU  1586670509        95  66.08   76.63
# ..              ...         ...     ...         ...       ...    ...     ...
# 571  drexel heights          90      US  1586670763        71  32.14 -111.03
# 572        la rioja          74      ES  1586670764        93  42.25   -2.50
# 574  gornopravdinsk          14      RU  1586670765        76  60.05   69.90
# 576           senno           0      RU  1586670766        76  59.53   33.92
# 577         talnakh          75      RU  1586670766        85  69.49   88.40
#
#      Max Temp  Wind Speed
# 0      302.10        2.14
# 3      285.15        3.10
# 4      296.09        6.32
# 5      268.88        4.21
# 6      267.15        3.13
# ..        ...         ...
# 571    284.82        3.07
# 572    284.15        2.10
# 574    281.47        2.18
# 576    274.96        1.36
# 577    265.15       15.00
#
# [409 rows x 9 columns]

# %%
southern_hem = test_city.loc[(test_city["Lat"]<0)]
southern_hem
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 1          ushuaia          40      AR  1586670284        64 -54.80  -68.30
# 2            vaini          40      TO  1586670508        74 -21.20 -175.20
# 8    mar del plata         100      AR  1586670331        93 -38.00  -57.56
# 10         tautira         100      PF  1586670512        74 -17.73 -149.15
# 11         te anau          83      NZ  1586670512        83 -45.42  167.72
# ..             ...         ...     ...         ...       ...    ...     ...
# 563        emerald           0      AU  1586670760        18 -23.53  148.17
# 567           tena         100      EC  1586670762        67  -0.98  -77.82
# 568       nokaneng          48      BW  1586670762        48 -19.67   22.27
# 573           lima           1      PE  1586669888        88 -12.04  -77.03
# 575         sorong          40      ID  1586670765        83  -0.88  131.25
#
#      Max Temp  Wind Speed
# 1      277.15        4.10
# 2      299.15        2.60
# 8      287.59        1.50
# 10     301.15        1.00
# 11     285.37        0.46
# ..        ...         ...
# 563    305.15        6.20
# 567    295.35        0.89
# 568    295.28        1.30
# 573    294.15        3.60
# 575    301.90        2.02
#
# [169 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
n_latitude = northern_hem.iloc[:,5]
n_temp = northern_hem.iloc[:,7]
nt_slope, nt_int, nt_r, nt_p, nt_std_err = stats.linregress(n_latitude, n_temp)
nt_fit = nt_slope * n_latitude + nt_int
plt.scatter(n_latitude, n_temp)
plt.plot(n_latitude,nt_fit,"r")#label='y={:.2f}x+{:.2f}'.format(t_slope,t_int))
#plt.annotate(line_equation_t,(5,10),fontsize=5)
plt.xlabel('NH Latitude')
plt.ylabel('NH Max Temperature (F)')
plt.title("NH City Latitude vs. NH Max Temperature " + str(date))
plt.grid()
#how to add current date
plt.savefig("NH City Latitude vs NH Max Temperature.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s_latitude = southern_hem.iloc[:,5]
s_temp = southern_hem.iloc[:,7]
st_slope, st_int, st_r, st_p, st_std_err = stats.linregress(s_latitude, s_temp)
st_fit = st_slope * s_latitude + st_int
plt.scatter(s_latitude, s_temp)
plt.plot(s_latitude,st_fit,"r")#label='y={:.2f}x+{:.2f}'.format(t_slope,t_int))
#plt.annotate(line_equation_t,(5,10),fontsize=5)
plt.xlabel('SH Latitude')
plt.ylabel('SH Max Temperature (F)')
plt.title("SH City Latitude vs. SH Max Temperature " + str(date))
plt.grid()
#how to add current date
plt.savefig("SH City Latitude vs SH Max Temperature.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
n_latitude = northern_hem.iloc[:,5]
n_humidity = northern_hem.iloc[:,4]
nh_slope, nh_int, nh_r, nh_p, nh_std_err = stats.linregress(n_latitude, n_humidity)
nh_fit = nh_slope * n_latitude + nh_int
plt.scatter(n_latitude, n_humidity)
plt.plot(n_latitude,nh_fit,"r")
plt.xlabel('NH Latitude')
plt.ylabel('NH Humidity')
plt.title("NH City Latitude vs. NH Humidity " + str(date))
#how to add current date
plt.grid()
plt.savefig("NH City Latitude vs NH Humidity.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s_latitude = southern_hem.iloc[:,5]
s_humidity = southern_hem.iloc[:,4]
sh_slope, sh_int, sh_r, sh_p, sh_std_err = stats.linregress(s_latitude, s_humidity)
sh_fit = sh_slope * s_latitude + sh_int
plt.scatter(s_latitude, s_humidity)
plt.plot(s_latitude,sh_fit,"r")
plt.xlabel('SH Latitude')
plt.ylabel('SH Humidity')
plt.title("SH City Latitude vs. SH Humidity " + str(date))
#how to add current date
plt.grid()
plt.savefig("SH City Latitude vs SH Humidity.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_latitude = northern_hem.iloc[:,5]
n_cloudiness = northern_hem.iloc[:,1]
nc_slope, nc_int, nc_r, nc_p, nc_std_err = stats.linregress(n_latitude, n_cloudiness)
nc_fit = nc_slope * n_latitude + nc_int
plt.scatter(n_latitude, n_cloudiness)
plt.plot(n_latitude,nc_fit,"r")
plt.xlabel('NH Latitude')
plt.ylabel('NH Cloudiness')
plt.title(f"NH City Latitude vs. NH Cloudiness {date}")
#how to add current date
plt.grid()
plt.savefig("NH City Latitude vs NH Cloudiness.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_latitude = southern_hem.iloc[:,5]
s_cloudiness = southern_hem.iloc[:,1]
sc_slope, sc_int, sc_r, sc_p, sc_std_err = stats.linregress(s_latitude, s_cloudiness)
sc_fit = sc_slope * s_latitude + sc_int
plt.scatter(s_latitude, s_cloudiness)
plt.plot(s_latitude,sc_fit,"r")
plt.xlabel('SH Latitude')
plt.ylabel('SH Cloudiness')
plt.title(f"SH City Latitude vs. SH Cloudiness {date}")
#how to add current date
plt.grid()
plt.savefig("SH City Latitude vs SH Cloudiness.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
n_latitude = northern_hem.iloc[:,5]
n_wind_speed = northern_hem.iloc[:,8]
nw_slope, nw_int, nw_r, nw_p, nw_std_err = stats.linregress(n_latitude, n_wind_speed)
nw_fit = nw_slope * n_latitude + nw_int
plt.scatter(n_latitude, n_wind_speed)
plt.plot(n_latitude,nw_fit,"r")
plt.xlabel('NH Latitude')
plt.ylabel('NH Wind Speed (MPH)')
plt.title(f"NH City Latitude vs. NH Wind Speed {date}")
#how to add current date
plt.grid()
plt.savefig("NH City Latitude vs NH Wind Speed.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_latitude = southern_hem.iloc[:,5]
s_wind_speed = southern_hem.iloc[:,8]
sw_slope, sw_int, sw_r, sw_p, sw_std_err = stats.linregress(s_latitude, s_wind_speed)
sw_fit = sw_slope * s_latitude + sw_int
plt.scatter(s_latitude, s_wind_speed)
plt.plot(s_latitude,sw_fit,"r")
plt.xlabel('SH Latitude')
plt.ylabel('SH Wind Speed (MPH)')
plt.title(f"SH City Latitude vs. SH Wind Speed {date}")
#how to add current date
plt.grid()
plt.savefig("SH City Latitude vs SH Wind Speed.png")
plt.show()

# %% [markdown]
# ## Observation:
# 1. Based on the data we can see that cities closer to the equator tend to have warmer temperatures than cities near    the northern, and southern poles.
# 2. Our random sample generated more cities in the northern hemisphere than the southern hemisphere, perhaps there      is data to prove that the northern hemisphere is more populated than the southern hemisphere.
# 3. The Wind Speed in the northern hemispheres is more uniform than Wind Speed in the southern hemisphere.
